# %%
#import helper
import pandas as pd
#from utils import *

import time
import numpy as np
import math
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader, Dataset
from torch import nn

from sklearn.decomposition import PCA

from IPython.display import Image

import pennylane as qml

# %% [markdown]
# # Introduction

# %% [markdown]
# Stock price prediction is one of the most rewarding problems in modern finance, where the accurate forecasting of future stock prices can yield significant profit and reduce the risks. LSTM (Long Short-Term Memory) is a recurrent Neural Network (RNN) applicable to a broad range of problems aiming to analyze or classify sequential data. Therefore, many people have used LSTM to predict the future stock price based on the historical data sequences with great success.
#
# On the other hand, recent studies have shown that the LSTM's efficiency and trainability can be improved by replacing some of the layers in the LSTM with variational quantum layers, thus making it a quantum-classical hybrid model of LSTM which we will call QLSTM for Quantum LSTM. In the study done by Samuel Yen-Chi Chen, Shinjae Yoo, and Yao-Lung L. Fang, they show that QLSTM offers better trainability compared to its classical counterpart as it proved to learn significantly more information after the first training epoch than its classical counterpart, learnt the local features better, all while having a comparable number of parameters. Inspired by these recent results, we proceed to test this variational quantum-classical hybrid neural network technique on stock price predictions.
#
# In the following notebook, we show a proof of concept that QLSTM can be used to great effect for stock price prediction, offering comparable and arguably better results than its classical counterpart. To do so, we implement both LSTM and QLSTM to predict the stock prices of the company Merck & Co. Inc (MRK) with the same number of features, of which we chose based on earlier studies done with stock price predictions.

# %% [markdown]
# This submission was motivated by a combination of a few separate studies:
#
# Stock price prediction use BERT and GAN: https://arxiv.org/pdf/2107.09055.pdf, Priyank Sonkiya, Vikas Bajpai, Anukriti Bansal <br>
# Quantum Long Short-Term Memory: https://arxiv.org/pdf/2009.01783.pdf, Samuel Yen-Chi Chen, Shinjae Yoo, and Yao-Lung L. Fang <br>
#
# With code and ideas reused and repurposed from the following sources:
#
# Example of a QLSTM: https://github.com/rdisipio/qlstm, Riccardo Di Sipio <br>
# How to use PyTorch LSTMs for time series regression: https://www.crosstab.io/articles/time-series-pytorch-lstm, Brian Kent <br>
# Using GANs to predict stock price movement: https://towardsdatascience.com/aifortrading-2edd6fac689d, Boris Banushev<br>

# %% [markdown]
# ## Brief Outline

# %% [markdown]
# To demonstrate the use of QLSTM for stock prediction, we use the stock prices of the company Merck & Co. Inc (MRK). The notebook will proceed in the following manner:
#
# 1. Brief description of Data
# 2. Using Classical LSTM to perform stock price prediction
# 3. Defining QLSTM and using it to perform stock price prediction
# 4. Comparison between LSTM and QLSTM
#
# Note that for the LSTM, we would be using PyTorch; while for the QLSTM we would be using PyTorch and Pennylane.

# %% [markdown]
# # Experimentation

# %% [markdown]
# - weight decay coefficient (weight decay),
# - width of the layer (width),
# - mini-batch size (batch size),
# - learning rate (learning rate),
# - dropout probability (dropout),
# - depth of the architecture(depth)
# - the choice of the optimization algorithms (optimizer)

# %% [markdown]
# number of iterations = batch_size * num_epochs

# %%
batch_size = 1
sequence_length = 3

weight_decay_value = 0
learning_rate = 0.0001

num_hidden_units = 32

# %%
#from torch.utils.tensorboard import SummaryWriter

# %%
#writer = SummaryWriter()

# %% [markdown]
# # Data

# %% [markdown]
# To briefly describe the data, we have collected the historical data of the MRK stock prices, of which we focus on the closing price. Our goal is then to forecast the closing stock prices of MRK using LSTM (or QLSTM).
#
# To achieve this goal, we have collected the data and information we thought necessary and important. This includes the following:
#
# - Technical indicators
# - Trend approximations (Fourier Transforms)
# - ARIMA
# - Correlated assets
# - Sentimental analysis
#
# While interesting and important in its own right, we have decided not to go into detail for the data collection in this notebook. For more information, please go take a look at the Data Collection notebook also in this Github.
#
# In this section, our goal is to process the data to get it ready for the LSTM and QLSTM.

# %% [markdown]
# First, we read in the data, dropping the index and the date.

# %%
df = pd.read_csv('dataset_MRK_prediction.csv')
df = df.drop(['Date' ,'Unnamed: 0'], axis=1)
df
# Out:
#           Close    Volume        ma7       ma21      26ema      12ema  \
# 0     31.011450  14227229  30.050436  29.200291  29.514006  29.867322
# 1     31.440840  20081566  30.318975  29.299346  29.688906  30.115697
# 2     31.183207  10438080  30.564340  29.420211  29.822316  30.283528
# 3     31.364504  10302154  30.858779  29.556525  29.957940  30.452906
# 4     30.839695  12640452  30.973283  29.664667  30.034423  30.513340
# ...         ...       ...        ...        ...        ...        ...
# 2712  78.301529  13675457  75.931026  74.702836  75.305196  75.725497
# 2713  77.814888   9292930  76.515814  74.863687  75.491099  76.046941
# 2714  78.492363  10413347  77.157852  75.097238  75.713415  76.423160
# 2715  79.103050   9956838  77.684024  75.428935  75.964499  76.835451
# 2716  78.492363   8846168  77.893947  75.695202  76.151748  77.090360
#
#           MACD      20sd  upper_band  lower_band  ...        GSK         LLY  \
# 0     0.353316  0.835852   30.871996   27.528586  ...  20.441219   22.546120
# 1     0.426791  0.963549   31.226444   27.372247  ...  20.290920   22.639698
# 2     0.461212  1.026446   31.473102   27.367319  ...  20.280550   22.492653
# 3     0.494965  1.086420   31.729366   27.383684  ...  20.513784   22.800129
# 4     0.478916  1.094567   31.853801   27.475534  ...  20.285738   22.459227
# ...        ...       ...         ...         ...  ...        ...         ...
# 2712  0.420300  1.705192   78.113220   71.292452  ...  38.856968  148.141144
# 2713  0.555842  1.816324   78.496336   71.231038  ...  38.423382  146.373550
# 2714  0.709745  1.857931   78.813100   71.381377  ...  38.469505  144.916718
# 2715  0.870952  1.960788   79.350511   71.507360  ...  39.087601  144.916718
# 2716  0.938612  2.043482   79.782166   71.608238  ...  38.635563  144.839020
#
#             NVS          NYSE       NASDAQ        FT3        FT6        FT9  \
# 0     26.214659   6671.140137  2017.979980  55.454947  50.337802  47.947327
# 1     26.532934   6697.220215  2024.229980  55.359252  50.140845  47.659130
# 2     26.608170   6687.939941  2024.430054  55.263482  49.944470  47.372320
# 3     26.984316   6722.310059  2027.729980  55.167638  49.748691  47.086936
# 4     26.857002   6709.040039  2028.770020  55.071723  49.553518  46.803017
# ...         ...           ...          ...        ...        ...        ...
# 2712  82.393753  12302.190430  9682.910156  57.910147  55.622779  55.790021
# 2713  81.836136  12286.980469  9615.809570  57.817099  55.415062  55.480641
# 2714  82.576424  12641.440430  9814.080078  57.723926  55.207594  55.171523
# 2715  82.364914  12836.599609  9924.750000  57.630627  55.000389  54.862711
# 2716  85.018433  12619.519531  9953.750000  57.537207  54.793461  54.554253
#
#           ARIMA  Close_lead1
# 0     31.011450    31.440840
# 1     31.440840    31.183207
# 2     31.183207    31.364504
# 3     31.364504    30.839695
# 4     30.839695    30.944656
# ...         ...          ...
# 2712  76.887436    77.814888
# 2713  78.191500    78.492363
# 2714  77.972240    79.103050
# 2715  78.309688    78.492363
# 2716  79.039159    78.024811
#
# [2717 rows x 34 columns]

# %% [markdown]
# We identify the dependent and independent variables:

# %%
target = "Close_lead1"

# %%
features = list(df.columns.difference(["Close", 'Close_lead1']))
features
# Out:
# ['12ema',
#  '20sd',
#  '26ema',
#  'AMGN',
#  'ARIMA',
#  'BMY',
#  'FT3',
#  'FT6',
#  'FT9',
#  'GSK',
#  'JNJ',
#  'LLY',
#  'MACD',
#  'NASDAQ',
#  'NVS',
#  'NYSE',
#  'PFE',
#  'SNP',
#  'SNY',
#  'VTRS',
#  'VZ',
#  'Volume',
#  'ema',
#  'log_momentum',
#  'lower_band',
#  'ma21',
#  'ma7',
#  'momentum',
#  'neg',
#  'neu',
#  'pos',
#  'upper_band']

# %% [markdown]
# ## Data Processing

# %% [markdown]
# To process the data, we first split it into training and test data, where two-thirds of the data is used for training, and the last third is used for testing.

# %%
size = int(len(df) * 0.67)

df_train = df.loc[:size].copy()
df_test = df.loc[size:].copy()

# %% [markdown]
# Next, in order to ensure that some values don't inherently dominate the features due to their magnitude, we standardize their values.

# %%
target_mean = df_train[target].mean()
target_stdev = df_train[target].std()

for c in df_train.columns:
    mean = df_train[c].mean()
    stdev = df_train[c].std()

    df_train[c] = (df_train[c] - mean) / stdev
    df_test[c] = (df_test[c] - mean) / stdev

# %%
class SequenceDataset(Dataset):
    def __init__(self, dataframe, target, features, sequence_length=5):
        self.features = features
        self.target = target
        self.sequence_length = sequence_length
        self.y = torch.tensor(dataframe[self.target].values).float()
        self.X = torch.tensor(dataframe[self.features].values).float()

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, i): 
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            x = torch.cat((padding, x), 0)

        return x, self.y[i]

# %% [markdown]
# Finally, the last step in the data processing to prepare it for LSTM is to prepare the data in a sequence of past observations. Preparing LSTM on time series data means that it uses a certain number of past observations to predict the future. In this case, the sequence length decides how many days the LSTM considers in advance. If the sequence length is $n$, then the LSTM considers the last $n$ observations to predict the $n+1$th day.
#
# The sequence length we decided on is 3 for purposes of this notebook.

# %%
torch.manual_seed(101)

#batch_size = 10
#sequence_length = 3

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([1, 3, 32])
# Target shape: torch.Size([1])

# %%
i = 0
for _ in train_loader:
    i += 1 
print(i)
# Out:
# 1821

# %% [markdown]
# # Classical LSTM

# %% [markdown]
# We first define two functions:
#
# - train_model: function to train the model based on the batches of data
# - test_model: function to test the model on the testing data
#
# For both, they print the loss at the end to let us know how the model is performing with regards to the data.

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()
    
    for X, y in data_loader:
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")
    return avg_loss

def test_model(data_loader, model, loss_function):
    
    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    return avg_loss

def trading_model(data_loader, model, loss_function, initial_inv, initial_price):
    
    # initial seed money
    inv = initial_inv
    
    # initial price of stock
    price = initial_price
    
    # initial number of stock 
    number_stocks = 0
    
    # predicted earnings
    pred_earn = 0 
    
    # predicted stock
    pred_output = []
    
    # day
    day = 1
    
    for X, y in data_loader:
        model.eval()
        with torch.no_grad():
            output = model(X)
            
            pred_price =  output * target_stdev + target_mean
            pred_output.append(pred_price)
            print("Today's stock price: ", price)
            print("Predicted stock price for tomorrow: ", pred_price)
            
            #if predicted value next day higher than today's price
            if pred_price > price:
                number_stocks = number_stocks + inv/price
                inv = 0
                print("Day", day, ": Bought ", number_stocks, "stocks at price ", price)
                pred_earn = pred_earn + number_stocks * (pred_price - price)
                print("Predicted earnings: ", pred_earn)
                
                
            #if predicted value next day lower than (or equal to)  today's price
            else:
                inv = inv + number_stocks * price
                print("Day", day, ": Sold ", number_stocks, "at price ", price)
                number_stocks = 0
            
            # Update price
            price = y * target_stdev + target_mean
            day += 1
            print("Current number of stocks: ", number_stocks)
            print("Current seed money:", inv)
        
        model.train()
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    total_earnings = number_stocks*price + inv
    print(f"Trading earnings: {total_earnings}")
    print(f"Predicted earnings: {pred_earn}")
    return pred_output

# %% [markdown]
# ## Running the Classical LSTM

# %% [markdown]
# To understand how we implemented QLSTM, we have to first understand how we implemented LSTM. LSTM follows the following structure:
#
# <img src="lstm2.jpg" alt="drawing" width="400"/>
#
# Image taken from: Quantum Long Short-Term Memory, https://arxiv.org/pdf/2009.01783.pdf. By Samuel Yen-Chi Chen, Shinjae Yoo, and Yao-Lung L. Fang
#
# Simply put, LSTM uses 4 neural network layers in each LSTM cell to perform its functions. They are:
#
# - Forget layer
# - Input layer
# - Update layer
# - Output layer
#
# You can see the corresponding layers in the W cells in the picture above. We will be skipping the technical details, as you can find better information on the theory elsewhere, but it is important to note that these 4 layers are the key to building an LSTM neural network model that we can train and eventually use to predict, and usually take the form of a normal NN layer (like a linear layer with reLU or convolutional layers).
#
# LSTMs are well studied, and there is a native implementation of it in PyTorch to begin with, so we use a slightly modified version of it for the time series LSTM that we perform here. The code for the time series LSTM was reused from:
#
# How to use PyTorch LSTMs for time series regression: https://www.crosstab.io/articles/time-series-pytorch-lstm, Brian Kent.
#
# In the following code, we train LSTM to predict future stock prices, and then test it on the test dataset. The learning rate of 0.0001 was decided after some experimentation, where we chose the learning rate that most reliably gave accurate results. The number of epochs we use is 20, by which it would have converged and thus would suffice for the purposes of this notebook. After that, we proceed to see 3 different graphs: the comparison between the real stock prices and the ones given by the model; and the evolution of test loss and training loss by epoch.

# %% [markdown]
# # Experimentation

# %%
class ShallowRegressionLSTM(nn.Module):
    def __init__(self, num_sensors, hidden_units):
        super().__init__()
        self.num_sensors = num_sensors  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = 1

        self.lstm = nn.LSTM(
            input_size=num_sensors,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).requires_grad_()
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).requires_grad_()
        
        _, (hn, _) = self.lstm(x, (h0, c0))
        out = self.linear(hn[0]).flatten()  # First dim of Hn is num_layers, which is set to 1 above.

        return out

# %%
#learning_rate = 0.0001
#num_hidden_units = 16

model = ShallowRegressionLSTM(num_sensors=len(features), hidden_units=num_hidden_units)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay= weight_decay_value)

# %%
classical_loss_train = []
classical_loss_test = []
classical_time = []
print("Untrained test\n--------")
start = time.time()
test_loss = test_model(test_loader, model, loss_function)
end = time.time()
print("Execution time", end - start)
classical_loss_test.append(test_loss)
classical_time.append(end - start)

for ix_epoch in range(20):
    print(f"Epoch {ix_epoch}\n---------")
    start = time.time()
    train_loss = train_model(train_loader, model, loss_function, optimizer=optimizer)
    test_loss = test_model(test_loader, model, loss_function)
    end = time.time()
    print("Execution time", end - start)
    classical_loss_train.append(train_loss)
    classical_loss_test.append(test_loss)
    classical_time.append(end - start)
# Out:
# Untrained test
# --------
# Test loss: 8.717945065652513
# Execution time 0.42699217796325684
# Epoch 0
# ---------
# C:\Users\jonas\Anaconda3\envs\qrnn\lib\site-packages\torch\autograd\__init__.py:173: UserWarning: CUDA initialization: CUDA driver initialization failed, you might not have a CUDA gpu. (Triggered internally at  C:\cb\pytorch_1000000000000\work\c10\cuda\CUDAFunctions.cpp:109.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Train loss: 0.17157381651319709
# Test loss: 1.8101156697285872
# Execution time 6.555729150772095
# Epoch 1
# ---------
# Train loss: 0.015688765803771876
# Test loss: 1.2793644568411084
# Execution time 6.940038442611694
# Epoch 2
# ---------
# Train loss: 0.009040473512920352
# Test loss: 1.2455822177148579
# Execution time 6.8174097537994385
# Epoch 3
# ---------
# Train loss: 0.007339356249954631
# Test loss: 1.1183740486365539
# Execution time 7.008583307266235
# Epoch 4
# ---------
# Train loss: 0.006662211224457453
# Test loss: 1.1935182357659262
# Execution time 7.0918238162994385
# Epoch 5
# ---------
# Train loss: 0.006236578386141527
# Test loss: 1.058024299737376
# Execution time 6.55476188659668
# Epoch 6
# ---------
# Train loss: 0.005856381544661344
# Test loss: 1.0036643367230789
# Execution time 7.002651929855347
# Epoch 7
# ---------
# Train loss: 0.005486668766179078
# Test loss: 0.9781843960308734
# Execution time 7.49958610534668
# Epoch 8
# ---------
# Train loss: 0.005280087979505642
# Test loss: 0.9997053022128134
# Execution time 7.262550592422485
# Epoch 9
# ---------
# Train loss: 0.005134419446048855
# Test loss: 0.8746564544669457
# Execution time 7.220473289489746
# Epoch 10
# ---------
# Train loss: 0.004937035850667942
# Test loss: 0.8864723674058235
# Execution time 7.32959246635437
# Epoch 11
# ---------
# Train loss: 0.004720932356781582
# Test loss: 0.8741884435850903
# Execution time 6.898384094238281
# Epoch 12
# ---------
# Train loss: 0.0046051831004752545
# Test loss: 0.8360150541254361
# Execution time 7.339213609695435
# Epoch 13
# ---------
# Train loss: 0.004538592137844162
# Test loss: 0.7725531848326782
# Execution time 7.18903112411499
# Epoch 14
# ---------
# Train loss: 0.004340498980876632
# Test loss: 0.7767894618721264
# Execution time 6.598823070526123
# Epoch 15
# ---------
# Train loss: 0.004312660893127712
# Test loss: 0.7951293000024754
# Execution time 6.611617803573608
# Epoch 16
# ---------
# Train loss: 0.0042045437541911425
# Test loss: 0.7567645465646596
# Execution time 6.9468536376953125
# Epoch 17
# ---------
# Train loss: 0.004115736168662932
# Test loss: 0.7015559666316108
# Execution time 7.170708894729614
# Epoch 18
# ---------
# Train loss: 0.004039817200950202
# Test loss: 0.6820265097747188
# Execution time 7.948866367340088
# Epoch 19
# ---------
# Train loss: 0.004016483524508584
# Test loss: 0.6741222677444477
# Execution time 7.904749155044556

# %% [markdown]
# We then use the model to predict the test set, and then compare the results of the prediction to the real values.

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            y_star = model(X)
            output = torch.cat((output, y_star), 0)
    
    return output

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)
# Out:
#       Close_lead1  Model forecast
# 0       31.440840       30.917503
# 1       31.183207       31.142399
# 2       31.364504       31.207573
# 3       30.839695       31.281651
# 4       30.944656       31.082140
# ...           ...             ...
# 2712    77.814888       65.399094
# 2713    78.492363       65.496407
# 2714    79.103050       65.626099
# 2715    78.492363       65.763046
# 2716    78.024811       65.780159
#
# [2718 rows x 2 columns]

# %%
df_out = df_out[~df_out.index.duplicated(keep='first')]

# %%
plt.figure(figsize=(12, 7))
plt.plot(range(len(df_out)), df_out["Close_lead1"], label = "Real")
plt.plot(range(len(df_out)), df_out["Model forecast"], label = "LSTM Prediction")
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.vlines(size, ymin = 30, ymax = 90, label = "Test set start", linestyles = "dashed")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(21), classical_loss_test)
plt.ylabel('Test Loss')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 21), classical_loss_train)
plt.ylabel('Train Loss')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # Trading

# %%
df_out["Close_lead1"][size - 1]
# Out:
# 60.620228

# %%
initial_inv = 10000
initial_price = df_out["Close_lead1"][size - 1]

# %%
pred_output = trading_model(test_loader, model, loss_function, initial_inv, initial_price)
# Out:
# Today's stock price:  60.620228
# Predicted stock price for tomorrow:  tensor([60.2619])
# Day 1 : Sold  0 at price  60.620228
# Current number of stocks:  0
# Current seed money: 10000.0
# Today's stock price:  tensor([60.7347])
# Predicted stock price for tomorrow:  tensor([61.0186])
# Day 2 : Bought  tensor([164.6504]) stocks at price  tensor([60.7347])
# Predicted earnings:  tensor([46.7357])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([59.7615])
# Predicted stock price for tomorrow:  tensor([60.8270])
# Day 3 : Bought  tensor([164.6504]) stocks at price  tensor([59.7615])
# Predicted earnings:  tensor([222.1817])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([59.8282])
# Predicted stock price for tomorrow:  tensor([60.5377])
# Day 4 : Bought  tensor([164.6504]) stocks at price  tensor([59.8282])
# Predicted earnings:  tensor([339.0011])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([59.0363])
# Predicted stock price for tomorrow:  tensor([60.0871])
# Day 5 : Bought  tensor([164.6504]) stocks at price  tensor([59.0363])
# Predicted earnings:  tensor([512.0215])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([59.4466])
# Predicted stock price for tomorrow:  tensor([59.9112])
# Day 6 : Bought  tensor([164.6504]) stocks at price  tensor([59.4466])
# Predicted earnings:  tensor([588.5205])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([58.8740])
# Predicted stock price for tomorrow:  tensor([60.0275])
# Day 7 : Bought  tensor([164.6504]) stocks at price  tensor([58.8740])
# Predicted earnings:  tensor([778.4416])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([58.8168])
# Predicted stock price for tomorrow:  tensor([59.5807])
# Day 8 : Bought  tensor([164.6504]) stocks at price  tensor([58.8168])
# Predicted earnings:  tensor([904.2213])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([59.3607])
# Predicted stock price for tomorrow:  tensor([59.4172])
# Day 9 : Bought  tensor([164.6504]) stocks at price  tensor([59.3607])
# Predicted earnings:  tensor([913.5234])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([58.9695])
# Predicted stock price for tomorrow:  tensor([59.3974])
# Day 10 : Bought  tensor([164.6504]) stocks at price  tensor([58.9695])
# Predicted earnings:  tensor([983.9764])
# Current number of stocks:  tensor([164.6504])
# Current seed money: 0
# Today's stock price:  tensor([59.3416])
# Predicted stock price for tomorrow:  tensor([59.2566])
# Day 11 : Sold  tensor([164.6504]) at price  tensor([59.3416])
# Current number of stocks:  0
# Current seed money: tensor([9770.6211])
# Today's stock price:  tensor([58.3874])
# Predicted stock price for tomorrow:  tensor([58.6367])
# Day 12 : Bought  tensor([167.3412]) stocks at price  tensor([58.3874])
# Predicted earnings:  tensor([1025.6956])
# Current number of stocks:  tensor([167.3412])
# Current seed money: 0
# Today's stock price:  tensor([57.9771])
# Predicted stock price for tomorrow:  tensor([58.0160])
# Day 13 : Bought  tensor([167.3412]) stocks at price  tensor([57.9771])
# Predicted earnings:  tensor([1032.2106])
# Current number of stocks:  tensor([167.3412])
# Current seed money: 0
# Today's stock price:  tensor([58.3302])
# Predicted stock price for tomorrow:  tensor([57.7869])
# Day 14 : Sold  tensor([167.3412]) at price  tensor([58.3302])
# Current number of stocks:  0
# Current seed money: tensor([9761.0410])
# Today's stock price:  tensor([57.4905])
# Predicted stock price for tomorrow:  tensor([57.5544])
# Day 15 : Bought  tensor([169.7854]) stocks at price  tensor([57.4905])
# Predicted earnings:  tensor([1043.0741])
# Current number of stocks:  tensor([169.7854])
# Current seed money: 0
# Today's stock price:  tensor([57.5191])
# Predicted stock price for tomorrow:  tensor([57.1688])
# Day 16 : Sold  tensor([169.7854]) at price  tensor([57.5191])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([57.3092])
# Predicted stock price for tomorrow:  tensor([57.1063])
# Day 17 : Sold  0 at price  tensor([57.3092])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([57.3664])
# Predicted stock price for tomorrow:  tensor([56.5995])
# Day 18 : Sold  0 at price  tensor([57.3664])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([58.4256])
# Predicted stock price for tomorrow:  tensor([57.2241])
# Day 19 : Sold  0 at price  tensor([58.4256])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([58.8931])
# Predicted stock price for tomorrow:  tensor([57.7395])
# Day 20 : Sold  0 at price  tensor([58.8931])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([58.9599])
# Predicted stock price for tomorrow:  tensor([57.9233])
# Day 21 : Sold  0 at price  tensor([58.9599])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([58.9695])
# Predicted stock price for tomorrow:  tensor([57.8267])
# Day 22 : Sold  0 at price  tensor([58.9695])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([59.5134])
# Predicted stock price for tomorrow:  tensor([58.2079])
# Day 23 : Sold  0 at price  tensor([59.5134])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([59.5802])
# Predicted stock price for tomorrow:  tensor([58.8353])
# Day 24 : Sold  0 at price  tensor([59.5802])
# Current number of stocks:  0
# Current seed money: tensor([9765.9004])
# Today's stock price:  tensor([58.3397])
# Predicted stock price for tomorrow:  tensor([58.4845])
# Day 25 : Bought  tensor([167.3972]) stocks at price  tensor([58.3397])
# Predicted earnings:  tensor([1067.3091])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([57.7290])
# Predicted stock price for tomorrow:  tensor([58.0714])
# Day 26 : Bought  tensor([167.3972]) stocks at price  tensor([57.7290])
# Predicted earnings:  tensor([1124.6290])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([56.7080])
# Predicted stock price for tomorrow:  tensor([57.2829])
# Day 27 : Bought  tensor([167.3972]) stocks at price  tensor([56.7080])
# Predicted earnings:  tensor([1220.8628])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([56.8511])
# Predicted stock price for tomorrow:  tensor([56.9962])
# Day 28 : Bought  tensor([167.3972]) stocks at price  tensor([56.8511])
# Predicted earnings:  tensor([1245.1393])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([56.8321])
# Predicted stock price for tomorrow:  tensor([57.0892])
# Day 29 : Bought  tensor([167.3972]) stocks at price  tensor([56.8321])
# Predicted earnings:  tensor([1288.1853])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([57.0515])
# Predicted stock price for tomorrow:  tensor([57.1859])
# Day 30 : Bought  tensor([167.3972]) stocks at price  tensor([57.0515])
# Predicted earnings:  tensor([1310.6744])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([56.5553])
# Predicted stock price for tomorrow:  tensor([56.8465])
# Day 31 : Bought  tensor([167.3972]) stocks at price  tensor([56.5553])
# Predicted earnings:  tensor([1359.4165])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([56.3359])
# Predicted stock price for tomorrow:  tensor([56.7661])
# Day 32 : Bought  tensor([167.3972]) stocks at price  tensor([56.3359])
# Predicted earnings:  tensor([1431.4319])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([56.1737])
# Predicted stock price for tomorrow:  tensor([56.6135])
# Day 33 : Bought  tensor([167.3972]) stocks at price  tensor([56.1737])
# Predicted earnings:  tensor([1505.0641])
# Current number of stocks:  tensor([167.3972])
# Current seed money: 0
# Today's stock price:  tensor([57.3950])
# Predicted stock price for tomorrow:  tensor([57.0714])
# Day 34 : Sold  tensor([167.3972]) at price  tensor([57.3950])
# Current number of stocks:  0
# Current seed money: tensor([9607.7676])
# Today's stock price:  tensor([57.3760])
# Predicted stock price for tomorrow:  tensor([57.2653])
# Day 35 : Sold  0 at price  tensor([57.3760])
# Current number of stocks:  0
# Current seed money: tensor([9607.7676])
# Today's stock price:  tensor([57.3569])
# Predicted stock price for tomorrow:  tensor([57.3900])
# Day 36 : Bought  tensor([167.5086]) stocks at price  tensor([57.3569])
# Predicted earnings:  tensor([1510.6150])
# Current number of stocks:  tensor([167.5086])
# Current seed money: 0
# Today's stock price:  tensor([57.5095])
# Predicted stock price for tomorrow:  tensor([57.3538])
# Day 37 : Sold  tensor([167.5086]) at price  tensor([57.5095])
# Current number of stocks:  0
# Current seed money: tensor([9633.3408])
# Today's stock price:  tensor([58.3015])
# Predicted stock price for tomorrow:  tensor([57.8917])
# Day 38 : Sold  0 at price  tensor([58.3015])
# Current number of stocks:  0
# Current seed money: tensor([9633.3408])
# Today's stock price:  tensor([57.1756])
# Predicted stock price for tomorrow:  tensor([57.8168])
# Day 39 : Bought  tensor([168.4870]) stocks at price  tensor([57.1756])
# Predicted earnings:  tensor([1618.6471])
# Current number of stocks:  tensor([168.4870])
# Current seed money: 0
# Today's stock price:  tensor([58.8073])
# Predicted stock price for tomorrow:  tensor([58.4645])
# Day 40 : Sold  tensor([168.4870]) at price  tensor([58.8073])
# Current number of stocks:  0
# Current seed money: tensor([9908.2568])
# Today's stock price:  tensor([59.3607])
# Predicted stock price for tomorrow:  tensor([59.0793])
# Day 41 : Sold  0 at price  tensor([59.3607])
# Current number of stocks:  0
# Current seed money: tensor([9908.2568])
# Today's stock price:  tensor([59.4847])
# Predicted stock price for tomorrow:  tensor([59.4178])
# Day 42 : Sold  0 at price  tensor([59.4847])
# Current number of stocks:  0
# Current seed money: tensor([9908.2568])
# Today's stock price:  tensor([58.6641])
# Predicted stock price for tomorrow:  tensor([59.1815])
# Day 43 : Bought  tensor([168.8981]) stocks at price  tensor([58.6641])
# Predicted earnings:  tensor([1706.0334])
# Current number of stocks:  tensor([168.8981])
# Current seed money: 0
# Today's stock price:  tensor([58.3683])
# Predicted stock price for tomorrow:  tensor([58.7201])
# Day 44 : Bought  tensor([168.8981]) stocks at price  tensor([58.3683])
# Predicted earnings:  tensor([1765.4548])
# Current number of stocks:  tensor([168.8981])
# Current seed money: 0
# Today's stock price:  tensor([57.5668])
# Predicted stock price for tomorrow:  tensor([58.3021])
# Day 45 : Bought  tensor([168.8981]) stocks at price  tensor([57.5668])
# Predicted earnings:  tensor([1889.6484])
# Current number of stocks:  tensor([168.8981])
# Current seed money: 0
# Today's stock price:  tensor([59.6660])
# Predicted stock price for tomorrow:  tensor([59.1154])
# Day 46 : Sold  tensor([168.8981]) at price  tensor([59.6660])
# Current number of stocks:  0
# Current seed money: tensor([10077.4766])
# Today's stock price:  tensor([58.9790])
# Predicted stock price for tomorrow:  tensor([59.3373])
# Day 47 : Bought  tensor([170.8655]) stocks at price  tensor([58.9790])
# Predicted earnings:  tensor([1950.8740])
# Current number of stocks:  tensor([170.8655])
# Current seed money: 0
# Today's stock price:  tensor([58.4065])
# Predicted stock price for tomorrow:  tensor([58.9961])
# Day 48 : Bought  tensor([170.8655]) stocks at price  tensor([58.4065])
# Predicted earnings:  tensor([2051.6216])
# Current number of stocks:  tensor([170.8655])
# Current seed money: 0
# Today's stock price:  tensor([58.2824])
# Predicted stock price for tomorrow:  tensor([58.8400])
# Day 49 : Bought  tensor([170.8655]) stocks at price  tensor([58.2824])
# Predicted earnings:  tensor([2146.8933])
# Current number of stocks:  tensor([170.8655])
# Current seed money: 0
# Today's stock price:  tensor([58.3969])
# Predicted stock price for tomorrow:  tensor([58.7645])
# Day 50 : Bought  tensor([170.8655]) stocks at price  tensor([58.3969])
# Predicted earnings:  tensor([2209.6956])
# Current number of stocks:  tensor([170.8655])
# Current seed money: 0
# Today's stock price:  tensor([58.9218])
# Predicted stock price for tomorrow:  tensor([58.8938])
# Day 51 : Sold  tensor([170.8655]) at price  tensor([58.9218])
# Current number of stocks:  0
# Current seed money: tensor([10067.6943])
# Today's stock price:  tensor([58.6164])
# Predicted stock price for tomorrow:  tensor([58.7491])
# Day 52 : Bought  tensor([171.7556]) stocks at price  tensor([58.6164])
# Predicted earnings:  tensor([2232.4905])
# Current number of stocks:  tensor([171.7556])
# Current seed money: 0
# Today's stock price:  tensor([59.1508])
# Predicted stock price for tomorrow:  tensor([58.8664])
# Day 53 : Sold  tensor([171.7556]) at price  tensor([59.1508])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([59.2557])
# Predicted stock price for tomorrow:  tensor([59.0678])
# Day 54 : Sold  0 at price  tensor([59.2557])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([61.2405])
# Predicted stock price for tomorrow:  tensor([60.1586])
# Day 55 : Sold  0 at price  tensor([61.2405])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([61.3454])
# Predicted stock price for tomorrow:  tensor([60.5851])
# Day 56 : Sold  0 at price  tensor([61.3454])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([61.9656])
# Predicted stock price for tomorrow:  tensor([60.8716])
# Day 57 : Sold  0 at price  tensor([61.9656])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([61.2595])
# Predicted stock price for tomorrow:  tensor([60.8216])
# Day 58 : Sold  0 at price  tensor([61.2595])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([61.3740])
# Predicted stock price for tomorrow:  tensor([60.7653])
# Day 59 : Sold  0 at price  tensor([61.3740])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([61.4408])
# Predicted stock price for tomorrow:  tensor([60.9194])
# Day 60 : Sold  0 at price  tensor([61.4408])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([61.2118])
# Predicted stock price for tomorrow:  tensor([61.0329])
# Day 61 : Sold  0 at price  tensor([61.2118])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([61.8034])
# Predicted stock price for tomorrow:  tensor([61.2311])
# Day 62 : Sold  0 at price  tensor([61.8034])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([62.6527])
# Predicted stock price for tomorrow:  tensor([62.2071])
# Day 63 : Sold  0 at price  tensor([62.6527])
# Current number of stocks:  0
# Current seed money: tensor([10159.4727])
# Today's stock price:  tensor([62.1756])
# Predicted stock price for tomorrow:  tensor([62.6842])
# Day 64 : Bought  tensor([163.3997]) stocks at price  tensor([62.1756])
# Predicted earnings:  tensor([2315.6047])
# Current number of stocks:  tensor([163.3997])
# Current seed money: 0
# Today's stock price:  tensor([62.2710])
# Predicted stock price for tomorrow:  tensor([62.3277])
# Day 65 : Bought  tensor([163.3997]) stocks at price  tensor([62.2710])
# Predicted earnings:  tensor([2324.8679])
# Current number of stocks:  tensor([163.3997])
# Current seed money: 0
# Today's stock price:  tensor([62.3950])
# Predicted stock price for tomorrow:  tensor([62.3634])
# Day 66 : Sold  tensor([163.3997]) at price  tensor([62.3950])
# Current number of stocks:  0
# Current seed money: tensor([10195.3340])
# Today's stock price:  tensor([62.4809])
# Predicted stock price for tomorrow:  tensor([62.4627])
# Day 67 : Sold  0 at price  tensor([62.4809])
# Current number of stocks:  0
# Current seed money: tensor([10195.3340])
# Today's stock price:  tensor([62.2996])
# Predicted stock price for tomorrow:  tensor([62.4480])
# Day 68 : Bought  tensor([163.6500]) stocks at price  tensor([62.2996])
# Predicted earnings:  tensor([2349.1565])
# Current number of stocks:  tensor([163.6500])
# Current seed money: 0
# Today's stock price:  tensor([62.8340])
# Predicted stock price for tomorrow:  tensor([62.8871])
# Day 69 : Bought  tensor([163.6500]) stocks at price  tensor([62.8340])
# Predicted earnings:  tensor([2357.8477])
# Current number of stocks:  tensor([163.6500])
# Current seed money: 0
# Today's stock price:  tensor([63.1298])
# Predicted stock price for tomorrow:  tensor([63.0164])
# Day 70 : Sold  tensor([163.6500]) at price  tensor([63.1298])
# Current number of stocks:  0
# Current seed money: tensor([10331.1885])
# Today's stock price:  tensor([62.8340])
# Predicted stock price for tomorrow:  tensor([62.8158])
# Day 71 : Sold  0 at price  tensor([62.8340])
# Current number of stocks:  0
# Current seed money: tensor([10331.1885])
# Today's stock price:  tensor([62.8531])
# Predicted stock price for tomorrow:  tensor([62.8771])
# Day 72 : Bought  tensor([164.3705]) stocks at price  tensor([62.8531])
# Predicted earnings:  tensor([2361.7935])
# Current number of stocks:  tensor([164.3705])
# Current seed money: 0
# Today's stock price:  tensor([63.1775])
# Predicted stock price for tomorrow:  tensor([63.1091])
# Day 73 : Sold  tensor([164.3705]) at price  tensor([63.1775])
# Current number of stocks:  0
# Current seed money: tensor([10384.5156])
# Today's stock price:  tensor([63.0534])
# Predicted stock price for tomorrow:  tensor([63.0088])
# Day 74 : Sold  0 at price  tensor([63.0534])
# Current number of stocks:  0
# Current seed money: tensor([10384.5156])
# Today's stock price:  tensor([63.5305])
# Predicted stock price for tomorrow:  tensor([63.1883])
# Day 75 : Sold  0 at price  tensor([63.5305])
# Current number of stocks:  0
# Current seed money: tensor([10384.5156])
# Today's stock price:  tensor([63.4256])
# Predicted stock price for tomorrow:  tensor([63.2341])
# Day 76 : Sold  0 at price  tensor([63.4256])
# Current number of stocks:  0
# Current seed money: tensor([10384.5156])
# Today's stock price:  tensor([62.9389])
# Predicted stock price for tomorrow:  tensor([63.1183])
# Day 77 : Bought  tensor([164.9935]) stocks at price  tensor([62.9389])
# Predicted earnings:  tensor([2391.3948])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([62.7863])
# Predicted stock price for tomorrow:  tensor([63.1095])
# Day 78 : Bought  tensor([164.9935]) stocks at price  tensor([62.7863])
# Predicted earnings:  tensor([2444.7314])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([62.8721])
# Predicted stock price for tomorrow:  tensor([62.9920])
# Day 79 : Bought  tensor([164.9935]) stocks at price  tensor([62.8721])
# Predicted earnings:  tensor([2464.5117])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([62.5954])
# Predicted stock price for tomorrow:  tensor([63.1022])
# Day 80 : Bought  tensor([164.9935]) stocks at price  tensor([62.5954])
# Predicted earnings:  tensor([2548.1238])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([61.2118])
# Predicted stock price for tomorrow:  tensor([62.6758])
# Day 81 : Bought  tensor([164.9935]) stocks at price  tensor([61.2118])
# Predicted earnings:  tensor([2789.6763])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([61.2595])
# Predicted stock price for tomorrow:  tensor([62.0173])
# Day 82 : Bought  tensor([164.9935]) stocks at price  tensor([61.2595])
# Predicted earnings:  tensor([2914.6973])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([61.7366])
# Predicted stock price for tomorrow:  tensor([62.1546])
# Day 83 : Bought  tensor([164.9935]) stocks at price  tensor([61.7366])
# Predicted earnings:  tensor([2983.6638])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([61.2405])
# Predicted stock price for tomorrow:  tensor([62.1486])
# Day 84 : Bought  tensor([164.9935]) stocks at price  tensor([61.2405])
# Predicted earnings:  tensor([3133.5071])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([60.9733])
# Predicted stock price for tomorrow:  tensor([61.8725])
# Day 85 : Bought  tensor([164.9935]) stocks at price  tensor([60.9733])
# Predicted earnings:  tensor([3281.8743])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([61.1737])
# Predicted stock price for tomorrow:  tensor([61.6830])
# Day 86 : Bought  tensor([164.9935]) stocks at price  tensor([61.1737])
# Predicted earnings:  tensor([3365.9155])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([60.9828])
# Predicted stock price for tomorrow:  tensor([61.4210])
# Day 87 : Bought  tensor([164.9935]) stocks at price  tensor([60.9828])
# Predicted earnings:  tensor([3438.2141])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([60.5916])
# Predicted stock price for tomorrow:  tensor([61.0844])
# Day 88 : Bought  tensor([164.9935]) stocks at price  tensor([60.5916])
# Predicted earnings:  tensor([3519.5239])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([60.3817])
# Predicted stock price for tomorrow:  tensor([60.7755])
# Day 89 : Bought  tensor([164.9935]) stocks at price  tensor([60.3817])
# Predicted earnings:  tensor([3584.4956])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([60.2863])
# Predicted stock price for tomorrow:  tensor([60.6842])
# Day 90 : Bought  tensor([164.9935]) stocks at price  tensor([60.2863])
# Predicted earnings:  tensor([3650.1553])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([60.2958])
# Predicted stock price for tomorrow:  tensor([60.5173])
# Day 91 : Bought  tensor([164.9935]) stocks at price  tensor([60.2958])
# Predicted earnings:  tensor([3686.6990])
# Current number of stocks:  tensor([164.9935])
# Current seed money: 0
# Today's stock price:  tensor([60.4389])
# Predicted stock price for tomorrow:  tensor([60.4112])
# Day 92 : Sold  tensor([164.9935]) at price  tensor([60.4389])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.7252])
# Predicted stock price for tomorrow:  tensor([60.3003])
# Day 93 : Sold  0 at price  tensor([60.7252])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.5439])
# Predicted stock price for tomorrow:  tensor([60.2010])
# Day 94 : Sold  0 at price  tensor([60.5439])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.6298])
# Predicted stock price for tomorrow:  tensor([60.1808])
# Day 95 : Sold  0 at price  tensor([60.6298])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.5630])
# Predicted stock price for tomorrow:  tensor([59.8882])
# Day 96 : Sold  0 at price  tensor([60.5630])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.7538])
# Predicted stock price for tomorrow:  tensor([60.2778])
# Day 97 : Sold  0 at price  tensor([60.7538])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.6584])
# Predicted stock price for tomorrow:  tensor([60.0539])
# Day 98 : Sold  0 at price  tensor([60.6584])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.3435])
# Predicted stock price for tomorrow:  tensor([59.9054])
# Day 99 : Sold  0 at price  tensor([60.3435])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.2385])
# Predicted stock price for tomorrow:  tensor([59.8243])
# Day 100 : Sold  0 at price  tensor([60.2385])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([59.6851])
# Predicted stock price for tomorrow:  tensor([59.6423])
# Day 101 : Sold  0 at price  tensor([59.6851])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([59.7137])
# Predicted stock price for tomorrow:  tensor([59.4905])
# Day 102 : Sold  0 at price  tensor([59.7137])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([60.1622])
# Predicted stock price for tomorrow:  tensor([59.3893])
# Day 103 : Sold  0 at price  tensor([60.1622])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([59.7424])
# Predicted stock price for tomorrow:  tensor([59.4256])
# Day 104 : Sold  0 at price  tensor([59.7424])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([59.9237])
# Predicted stock price for tomorrow:  tensor([59.5375])
# Day 105 : Sold  0 at price  tensor([59.9237])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([59.4179])
# Predicted stock price for tomorrow:  tensor([59.3243])
# Day 106 : Sold  0 at price  tensor([59.4179])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([59.7710])
# Predicted stock price for tomorrow:  tensor([59.3781])
# Day 107 : Sold  0 at price  tensor([59.7710])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([59.6851])
# Predicted stock price for tomorrow:  tensor([59.5183])
# Day 108 : Sold  0 at price  tensor([59.6851])
# Current number of stocks:  0
# Current seed money: tensor([9972.0312])
# Today's stock price:  tensor([59.0553])
# Predicted stock price for tomorrow:  tensor([59.2135])
# Day 109 : Bought  tensor([168.8591]) stocks at price  tensor([59.0553])
# Predicted earnings:  tensor([3713.4131])
# Current number of stocks:  tensor([168.8591])
# Current seed money: 0
# Today's stock price:  tensor([59.2939])
# Predicted stock price for tomorrow:  tensor([59.3317])
# Day 110 : Bought  tensor([168.8591]) stocks at price  tensor([59.2939])
# Predicted earnings:  tensor([3719.7966])
# Current number of stocks:  tensor([168.8591])
# Current seed money: 0
# Today's stock price:  tensor([59.4466])
# Predicted stock price for tomorrow:  tensor([59.6331])
# Day 111 : Bought  tensor([168.8591]) stocks at price  tensor([59.4466])
# Predicted earnings:  tensor([3751.2915])
# Current number of stocks:  tensor([168.8591])
# Current seed money: 0
# Today's stock price:  tensor([59.8282])
# Predicted stock price for tomorrow:  tensor([59.6909])
# Day 112 : Sold  tensor([168.8591]) at price  tensor([59.8282])
# Current number of stocks:  0
# Current seed money: tensor([10102.5420])
# Today's stock price:  tensor([59.7137])
# Predicted stock price for tomorrow:  tensor([59.7192])
# Day 113 : Bought  tensor([169.1829]) stocks at price  tensor([59.7137])
# Predicted earnings:  tensor([3752.2195])
# Current number of stocks:  tensor([169.1829])
# Current seed money: 0
# Today's stock price:  tensor([59.4752])
# Predicted stock price for tomorrow:  tensor([59.6647])
# Day 114 : Bought  tensor([169.1829]) stocks at price  tensor([59.4752])
# Predicted earnings:  tensor([3784.2832])
# Current number of stocks:  tensor([169.1829])
# Current seed money: 0
# Today's stock price:  tensor([59.5229])
# Predicted stock price for tomorrow:  tensor([59.7453])
# Day 115 : Bought  tensor([169.1829]) stocks at price  tensor([59.5229])
# Predicted earnings:  tensor([3821.9121])
# Current number of stocks:  tensor([169.1829])
# Current seed money: 0
# Today's stock price:  tensor([59.8282])
# Predicted stock price for tomorrow:  tensor([60.0159])
# Day 116 : Bought  tensor([169.1829]) stocks at price  tensor([59.8282])
# Predicted earnings:  tensor([3853.6572])
# Current number of stocks:  tensor([169.1829])
# Current seed money: 0
# Today's stock price:  tensor([60.7156])
# Predicted stock price for tomorrow:  tensor([60.2567])
# Day 117 : Sold  tensor([169.1829]) at price  tensor([60.7156])
# Current number of stocks:  0
# Current seed money: tensor([10272.0469])
# Today's stock price:  tensor([60.4771])
# Predicted stock price for tomorrow:  tensor([60.3692])
# Day 118 : Sold  0 at price  tensor([60.4771])
# Current number of stocks:  0
# Current seed money: tensor([10272.0469])
# Today's stock price:  tensor([61.0401])
# Predicted stock price for tomorrow:  tensor([60.7540])
# Day 119 : Sold  0 at price  tensor([61.0401])
# Current number of stocks:  0
# Current seed money: tensor([10272.0469])
# Today's stock price:  tensor([61.0782])
# Predicted stock price for tomorrow:  tensor([60.8410])
# Day 120 : Sold  0 at price  tensor([61.0782])
# Current number of stocks:  0
# Current seed money: tensor([10272.0469])
# Today's stock price:  tensor([60.3912])
# Predicted stock price for tomorrow:  tensor([60.7857])
# Day 121 : Bought  tensor([170.0917]) stocks at price  tensor([60.3912])
# Predicted earnings:  tensor([3920.7559])
# Current number of stocks:  tensor([170.0917])
# Current seed money: 0
# Today's stock price:  tensor([61.0115])
# Predicted stock price for tomorrow:  tensor([60.9324])
# Day 122 : Sold  tensor([170.0917]) at price  tensor([61.0115])
# Current number of stocks:  0
# Current seed money: tensor([10377.5430])
# Today's stock price:  tensor([61.4790])
# Predicted stock price for tomorrow:  tensor([61.2004])
# Day 123 : Sold  0 at price  tensor([61.4790])
# Current number of stocks:  0
# Current seed money: tensor([10377.5430])
# Today's stock price:  tensor([60.6584])
# Predicted stock price for tomorrow:  tensor([61.0065])
# Day 124 : Bought  tensor([171.0817]) stocks at price  tensor([60.6584])
# Predicted earnings:  tensor([3980.3020])
# Current number of stocks:  tensor([171.0817])
# Current seed money: 0
# Today's stock price:  tensor([60.6011])
# Predicted stock price for tomorrow:  tensor([61.1046])
# Day 125 : Bought  tensor([171.0817]) stocks at price  tensor([60.6011])
# Predicted earnings:  tensor([4066.4258])
# Current number of stocks:  tensor([171.0817])
# Current seed money: 0
# Today's stock price:  tensor([60.8683])
# Predicted stock price for tomorrow:  tensor([60.8589])
# Day 126 : Sold  tensor([171.0817]) at price  tensor([60.8683])
# Current number of stocks:  0
# Current seed money: tensor([10413.4570])
# Today's stock price:  tensor([60.1145])
# Predicted stock price for tomorrow:  tensor([60.6029])
# Day 127 : Bought  tensor([173.2270]) stocks at price  tensor([60.1145])
# Predicted earnings:  tensor([4151.0356])
# Current number of stocks:  tensor([173.2270])
# Current seed money: 0
# Today's stock price:  tensor([60.9637])
# Predicted stock price for tomorrow:  tensor([60.6217])
# Day 128 : Sold  tensor([173.2270]) at price  tensor([60.9637])
# Current number of stocks:  0
# Current seed money: tensor([10560.5674])
# Today's stock price:  tensor([60.8588])
# Predicted stock price for tomorrow:  tensor([60.8215])
# Day 129 : Sold  0 at price  tensor([60.8588])
# Current number of stocks:  0
# Current seed money: tensor([10560.5674])
# Today's stock price:  tensor([61.1069])
# Predicted stock price for tomorrow:  tensor([61.0316])
# Day 130 : Sold  0 at price  tensor([61.1069])
# Current number of stocks:  0
# Current seed money: tensor([10560.5674])
# Today's stock price:  tensor([61.5935])
# Predicted stock price for tomorrow:  tensor([61.1638])
# Day 131 : Sold  0 at price  tensor([61.5935])
# Current number of stocks:  0
# Current seed money: tensor([10560.5674])
# Today's stock price:  tensor([61.9561])
# Predicted stock price for tomorrow:  tensor([61.3576])
# Day 132 : Sold  0 at price  tensor([61.9561])
# Current number of stocks:  0
# Current seed money: tensor([10560.5674])
# Today's stock price:  tensor([62.0611])
# Predicted stock price for tomorrow:  tensor([61.5455])
# Day 133 : Sold  0 at price  tensor([62.0611])
# Current number of stocks:  0
# Current seed money: tensor([10560.5674])
# Today's stock price:  tensor([61.9466])
# Predicted stock price for tomorrow:  tensor([61.5933])
# Day 134 : Sold  0 at price  tensor([61.9466])
# Current number of stocks:  0
# Current seed money: tensor([10560.5674])
# Today's stock price:  tensor([61.9084])
# Predicted stock price for tomorrow:  tensor([61.9288])
# Day 135 : Bought  tensor([170.5838]) stocks at price  tensor([61.9084])
# Predicted earnings:  tensor([4154.5093])
# Current number of stocks:  tensor([170.5838])
# Current seed money: 0
# Today's stock price:  tensor([62.1279])
# Predicted stock price for tomorrow:  tensor([61.9260])
# Day 136 : Sold  tensor([170.5838]) at price  tensor([62.1279])
# Current number of stocks:  0
# Current seed money: tensor([10598.0049])
# Today's stock price:  tensor([62.2710])
# Predicted stock price for tomorrow:  tensor([61.9874])
# Day 137 : Sold  0 at price  tensor([62.2710])
# Current number of stocks:  0
# Current seed money: tensor([10598.0049])
# Today's stock price:  tensor([62.4714])
# Predicted stock price for tomorrow:  tensor([62.2179])
# Day 138 : Sold  0 at price  tensor([62.4714])
# Current number of stocks:  0
# Current seed money: tensor([10598.0049])
# Today's stock price:  tensor([62.0897])
# Predicted stock price for tomorrow:  tensor([62.2477])
# Day 139 : Bought  tensor([170.6886]) stocks at price  tensor([62.0897])
# Predicted earnings:  tensor([4181.4810])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([61.7080])
# Predicted stock price for tomorrow:  tensor([62.0937])
# Day 140 : Bought  tensor([170.6886]) stocks at price  tensor([61.7080])
# Predicted earnings:  tensor([4247.3125])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([61.1260])
# Predicted stock price for tomorrow:  tensor([61.9095])
# Day 141 : Bought  tensor([170.6886]) stocks at price  tensor([61.1260])
# Predicted earnings:  tensor([4381.0591])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([60.3053])
# Predicted stock price for tomorrow:  tensor([61.6772])
# Day 142 : Bought  tensor([170.6886]) stocks at price  tensor([60.3053])
# Predicted earnings:  tensor([4615.2251])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([61.4408])
# Predicted stock price for tomorrow:  tensor([61.6068])
# Day 143 : Bought  tensor([170.6886]) stocks at price  tensor([61.4408])
# Predicted earnings:  tensor([4643.5581])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([61.4408])
# Predicted stock price for tomorrow:  tensor([62.0479])
# Day 144 : Bought  tensor([170.6886]) stocks at price  tensor([61.4408])
# Predicted earnings:  tensor([4747.1821])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([60.3721])
# Predicted stock price for tomorrow:  tensor([61.6138])
# Day 145 : Bought  tensor([170.6886]) stocks at price  tensor([60.3721])
# Predicted earnings:  tensor([4959.1182])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([60.4676])
# Predicted stock price for tomorrow:  tensor([61.1225])
# Day 146 : Bought  tensor([170.6886]) stocks at price  tensor([60.4676])
# Predicted earnings:  tensor([5070.9067])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([60.2958])
# Predicted stock price for tomorrow:  tensor([60.9357])
# Day 147 : Bought  tensor([170.6886]) stocks at price  tensor([60.2958])
# Predicted earnings:  tensor([5180.1270])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([60.0859])
# Predicted stock price for tomorrow:  tensor([60.8389])
# Day 148 : Bought  tensor([170.6886]) stocks at price  tensor([60.0859])
# Predicted earnings:  tensor([5308.6592])
# Current number of stocks:  tensor([170.6886])
# Current seed money: 0
# Today's stock price:  tensor([60.7634])
# Predicted stock price for tomorrow:  tensor([60.7591])
# Day 149 : Sold  tensor([170.6886]) at price  tensor([60.7634])
# Current number of stocks:  0
# Current seed money: tensor([10371.6143])
# Today's stock price:  tensor([61.5744])
# Predicted stock price for tomorrow:  tensor([61.0406])
# Day 150 : Sold  0 at price  tensor([61.5744])
# Current number of stocks:  0
# Current seed money: tensor([10371.6143])
# Today's stock price:  tensor([62.4618])
# Predicted stock price for tomorrow:  tensor([61.5631])
# Day 151 : Sold  0 at price  tensor([62.4618])
# Current number of stocks:  0
# Current seed money: tensor([10371.6143])
# Today's stock price:  tensor([62.9962])
# Predicted stock price for tomorrow:  tensor([61.9159])
# Day 152 : Sold  0 at price  tensor([62.9962])
# Current number of stocks:  0
# Current seed money: tensor([10371.6143])
# Today's stock price:  tensor([63.1298])
# Predicted stock price for tomorrow:  tensor([61.9737])
# Day 153 : Sold  0 at price  tensor([63.1298])
# Current number of stocks:  0
# Current seed money: tensor([10371.6143])
# Today's stock price:  tensor([62.9008])
# Predicted stock price for tomorrow:  tensor([62.0323])
# Day 154 : Sold  0 at price  tensor([62.9008])
# Current number of stocks:  0
# Current seed money: tensor([10371.6143])
# Today's stock price:  tensor([62.5382])
# Predicted stock price for tomorrow:  tensor([62.1692])
# Day 155 : Sold  0 at price  tensor([62.5382])
# Current number of stocks:  0
# Current seed money: tensor([10371.6143])
# Today's stock price:  tensor([62.1756])
# Predicted stock price for tomorrow:  tensor([61.9803])
# Day 156 : Sold  0 at price  tensor([62.1756])
# Current number of stocks:  0
# Current seed money: tensor([10371.6143])
# Today's stock price:  tensor([61.3931])
# Predicted stock price for tomorrow:  tensor([61.6815])
# Day 157 : Bought  tensor([168.9377]) stocks at price  tensor([61.3931])
# Predicted earnings:  tensor([5357.3813])
# Current number of stocks:  tensor([168.9377])
# Current seed money: 0
# Today's stock price:  tensor([61.1546])
# Predicted stock price for tomorrow:  tensor([61.2455])
# Day 158 : Bought  tensor([168.9377]) stocks at price  tensor([61.1546])
# Predicted earnings:  tensor([5372.7437])
# Current number of stocks:  tensor([168.9377])
# Current seed money: 0
# Today's stock price:  tensor([61.3263])
# Predicted stock price for tomorrow:  tensor([61.3154])
# Day 159 : Sold  tensor([168.9377]) at price  tensor([61.3263])
# Current number of stocks:  0
# Current seed money: tensor([10360.3301])
# Today's stock price:  tensor([61.2214])
# Predicted stock price for tomorrow:  tensor([61.2406])
# Day 160 : Bought  tensor([169.2273]) stocks at price  tensor([61.2214])
# Predicted earnings:  tensor([5376.0039])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([60.2099])
# Predicted stock price for tomorrow:  tensor([61.2392])
# Day 161 : Bought  tensor([169.2273]) stocks at price  tensor([60.2099])
# Predicted earnings:  tensor([5550.1904])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([60.2672])
# Predicted stock price for tomorrow:  tensor([60.6298])
# Day 162 : Bought  tensor([169.2273]) stocks at price  tensor([60.2672])
# Predicted earnings:  tensor([5611.5635])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([59.9523])
# Predicted stock price for tomorrow:  tensor([60.4695])
# Day 163 : Bought  tensor([169.2273]) stocks at price  tensor([59.9523])
# Predicted earnings:  tensor([5699.0903])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([59.4847])
# Predicted stock price for tomorrow:  tensor([60.1196])
# Day 164 : Bought  tensor([169.2273]) stocks at price  tensor([59.4847])
# Predicted earnings:  tensor([5806.5288])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([59.9046])
# Predicted stock price for tomorrow:  tensor([60.2381])
# Day 165 : Bought  tensor([169.2273]) stocks at price  tensor([59.9046])
# Predicted earnings:  tensor([5862.9629])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([60.0095])
# Predicted stock price for tomorrow:  tensor([60.3402])
# Day 166 : Bought  tensor([169.2273]) stocks at price  tensor([60.0095])
# Predicted earnings:  tensor([5918.9272])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([60.1718])
# Predicted stock price for tomorrow:  tensor([60.3662])
# Day 167 : Bought  tensor([169.2273]) stocks at price  tensor([60.1718])
# Predicted earnings:  tensor([5951.8271])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([59.7424])
# Predicted stock price for tomorrow:  tensor([60.0918])
# Day 168 : Bought  tensor([169.2273]) stocks at price  tensor([59.7424])
# Predicted earnings:  tensor([6010.9575])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([59.5515])
# Predicted stock price for tomorrow:  tensor([59.8432])
# Day 169 : Bought  tensor([169.2273]) stocks at price  tensor([59.5515])
# Predicted earnings:  tensor([6060.3145])
# Current number of stocks:  tensor([169.2273])
# Current seed money: 0
# Today's stock price:  tensor([59.7519])
# Predicted stock price for tomorrow:  tensor([59.7272])
# Day 170 : Sold  tensor([169.2273]) at price  tensor([59.7519])
# Current number of stocks:  0
# Current seed money: tensor([10111.6562])
# Today's stock price:  tensor([60.0573])
# Predicted stock price for tomorrow:  tensor([60.1267])
# Day 171 : Bought  tensor([168.3670]) stocks at price  tensor([60.0573])
# Predicted earnings:  tensor([6072.0142])
# Current number of stocks:  tensor([168.3670])
# Current seed money: 0
# Today's stock price:  tensor([59.7615])
# Predicted stock price for tomorrow:  tensor([59.9227])
# Day 172 : Bought  tensor([168.3670]) stocks at price  tensor([59.7615])
# Predicted earnings:  tensor([6099.1602])
# Current number of stocks:  tensor([168.3670])
# Current seed money: 0
# Today's stock price:  tensor([59.7042])
# Predicted stock price for tomorrow:  tensor([59.8168])
# Day 173 : Bought  tensor([168.3670]) stocks at price  tensor([59.7042])
# Predicted earnings:  tensor([6118.1123])
# Current number of stocks:  tensor([168.3670])
# Current seed money: 0
# Today's stock price:  tensor([59.5038])
# Predicted stock price for tomorrow:  tensor([59.6211])
# Day 174 : Bought  tensor([168.3670]) stocks at price  tensor([59.5038])
# Predicted earnings:  tensor([6137.8613])
# Current number of stocks:  tensor([168.3670])
# Current seed money: 0
# Today's stock price:  tensor([58.9695])
# Predicted stock price for tomorrow:  tensor([59.2570])
# Day 175 : Bought  tensor([168.3670]) stocks at price  tensor([58.9695])
# Predicted earnings:  tensor([6186.2705])
# Current number of stocks:  tensor([168.3670])
# Current seed money: 0
# Today's stock price:  tensor([60.7729])
# Predicted stock price for tomorrow:  tensor([59.9825])
# Day 176 : Sold  tensor([168.3670]) at price  tensor([60.7729])
# Current number of stocks:  0
# Current seed money: tensor([10232.1484])
# Today's stock price:  tensor([61.1737])
# Predicted stock price for tomorrow:  tensor([60.5184])
# Day 177 : Sold  0 at price  tensor([61.1737])
# Current number of stocks:  0
# Current seed money: tensor([10232.1484])
# Today's stock price:  tensor([60.9542])
# Predicted stock price for tomorrow:  tensor([60.5841])
# Day 178 : Sold  0 at price  tensor([60.9542])
# Current number of stocks:  0
# Current seed money: tensor([10232.1484])
# Today's stock price:  tensor([60.9924])
# Predicted stock price for tomorrow:  tensor([60.5051])
# Day 179 : Sold  0 at price  tensor([60.9924])
# Current number of stocks:  0
# Current seed money: tensor([10232.1484])
# Today's stock price:  tensor([60.5344])
# Predicted stock price for tomorrow:  tensor([60.3634])
# Day 180 : Sold  0 at price  tensor([60.5344])
# Current number of stocks:  0
# Current seed money: tensor([10232.1484])
# Today's stock price:  tensor([60.6107])
# Predicted stock price for tomorrow:  tensor([60.1881])
# Day 181 : Sold  0 at price  tensor([60.6107])
# Current number of stocks:  0
# Current seed money: tensor([10232.1484])
# Today's stock price:  tensor([60.2099])
# Predicted stock price for tomorrow:  tensor([60.0451])
# Day 182 : Sold  0 at price  tensor([60.2099])
# Current number of stocks:  0
# Current seed money: tensor([10232.1484])
# Today's stock price:  tensor([59.9618])
# Predicted stock price for tomorrow:  tensor([59.9297])
# Day 183 : Sold  0 at price  tensor([59.9618])
# Current number of stocks:  0
# Current seed money: tensor([10232.1484])
# Today's stock price:  tensor([59.4656])
# Predicted stock price for tomorrow:  tensor([59.8423])
# Day 184 : Bought  tensor([172.0682]) stocks at price  tensor([59.4656])
# Predicted earnings:  tensor([6251.0835])
# Current number of stocks:  tensor([172.0682])
# Current seed money: 0
# Today's stock price:  tensor([59.6279])
# Predicted stock price for tomorrow:  tensor([59.5828])
# Day 185 : Sold  tensor([172.0682]) at price  tensor([59.6279])
# Current number of stocks:  0
# Current seed money: tensor([10260.0605])
# Today's stock price:  tensor([59.3321])
# Predicted stock price for tomorrow:  tensor([59.3218])
# Day 186 : Sold  0 at price  tensor([59.3321])
# Current number of stocks:  0
# Current seed money: tensor([10260.0605])
# Today's stock price:  tensor([59.5229])
# Predicted stock price for tomorrow:  tensor([59.2699])
# Day 187 : Sold  0 at price  tensor([59.5229])
# Current number of stocks:  0
# Current seed money: tensor([10260.0605])
# Today's stock price:  tensor([59.7996])
# Predicted stock price for tomorrow:  tensor([59.6450])
# Day 188 : Sold  0 at price  tensor([59.7996])
# Current number of stocks:  0
# Current seed money: tensor([10260.0605])
# Today's stock price:  tensor([59.6374])
# Predicted stock price for tomorrow:  tensor([59.7293])
# Day 189 : Bought  tensor([172.0407]) stocks at price  tensor([59.6374])
# Predicted earnings:  tensor([6266.8926])
# Current number of stocks:  tensor([172.0407])
# Current seed money: 0
# Today's stock price:  tensor([59.8282])
# Predicted stock price for tomorrow:  tensor([59.4318])
# Day 190 : Sold  tensor([172.0407]) at price  tensor([59.8282])
# Current number of stocks:  0
# Current seed money: tensor([10292.8926])
# Today's stock price:  tensor([59.0076])
# Predicted stock price for tomorrow:  tensor([59.3419])
# Day 191 : Bought  tensor([174.4332]) stocks at price  tensor([59.0076])
# Predicted earnings:  tensor([6325.1938])
# Current number of stocks:  tensor([174.4332])
# Current seed money: 0
# Today's stock price:  tensor([58.6737])
# Predicted stock price for tomorrow:  tensor([58.8625])
# Day 192 : Bought  tensor([174.4332]) stocks at price  tensor([58.6737])
# Predicted earnings:  tensor([6358.1348])
# Current number of stocks:  tensor([174.4332])
# Current seed money: 0
# Today's stock price:  tensor([59.1317])
# Predicted stock price for tomorrow:  tensor([58.9458])
# Day 193 : Sold  tensor([174.4332]) at price  tensor([59.1317])
# Current number of stocks:  0
# Current seed money: tensor([10314.5303])
# Today's stock price:  tensor([59.5611])
# Predicted stock price for tomorrow:  tensor([59.1580])
# Day 194 : Sold  0 at price  tensor([59.5611])
# Current number of stocks:  0
# Current seed money: tensor([10314.5303])
# Today's stock price:  tensor([59.3034])
# Predicted stock price for tomorrow:  tensor([59.1757])
# Day 195 : Sold  0 at price  tensor([59.3034])
# Current number of stocks:  0
# Current seed money: tensor([10314.5303])
# Today's stock price:  tensor([59.8378])
# Predicted stock price for tomorrow:  tensor([59.3691])
# Day 196 : Sold  0 at price  tensor([59.8378])
# Current number of stocks:  0
# Current seed money: tensor([10314.5303])
# Today's stock price:  tensor([60.0573])
# Predicted stock price for tomorrow:  tensor([59.5498])
# Day 197 : Sold  0 at price  tensor([60.0573])
# Current number of stocks:  0
# Current seed money: tensor([10314.5303])
# Today's stock price:  tensor([60.4198])
# ...
# Predicted stock price for tomorrow:  tensor([77.0544])
# Day 833 : Bought  tensor([168.3987]) stocks at price  tensor([75.3435])
# Predicted earnings:  tensor([50243.1289])
# Current number of stocks:  tensor([168.3987])
# Current seed money: 0
# Today's stock price:  tensor([78.2634])
# Predicted stock price for tomorrow:  tensor([77.8499])
# Day 834 : Sold  tensor([168.3987]) at price  tensor([78.2634])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([75.6202])
# Predicted stock price for tomorrow:  tensor([75.1526])
# Day 835 : Sold  0 at price  tensor([75.6202])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([71.0401])
# Predicted stock price for tomorrow:  tensor([70.7335])
# Day 836 : Sold  0 at price  tensor([71.0401])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([73.2347])
# Predicted stock price for tomorrow:  tensor([69.8359])
# Day 837 : Sold  0 at price  tensor([73.2347])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([66.7176])
# Predicted stock price for tomorrow:  tensor([65.1084])
# Day 838 : Sold  0 at price  tensor([66.7176])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([71.0687])
# Predicted stock price for tomorrow:  tensor([68.0429])
# Day 839 : Sold  0 at price  tensor([71.0687])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([68.3492])
# Predicted stock price for tomorrow:  tensor([66.7207])
# Day 840 : Sold  0 at price  tensor([68.3492])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([67.4905])
# Predicted stock price for tomorrow:  tensor([65.4139])
# Day 841 : Sold  0 at price  tensor([67.4905])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([68.0916])
# Predicted stock price for tomorrow:  tensor([64.6214])
# Day 842 : Sold  0 at price  tensor([68.0916])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([63.3588])
# Predicted stock price for tomorrow:  tensor([60.6657])
# Day 843 : Sold  0 at price  tensor([63.3588])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([65.8874])
# Predicted stock price for tomorrow:  tensor([61.5860])
# Day 844 : Sold  0 at price  tensor([65.8874])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([65.0954])
# Predicted stock price for tomorrow:  tensor([61.9029])
# Day 845 : Sold  0 at price  tensor([65.0954])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([70.1622])
# Predicted stock price for tomorrow:  tensor([65.4000])
# Day 846 : Sold  0 at price  tensor([70.1622])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([68.4447])
# Predicted stock price for tomorrow:  tensor([65.0961])
# Day 847 : Sold  0 at price  tensor([68.4447])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([73.4256])
# Predicted stock price for tomorrow:  tensor([70.4044])
# Day 848 : Sold  0 at price  tensor([73.4256])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([73.4160])
# Predicted stock price for tomorrow:  tensor([72.5632])
# Day 849 : Sold  0 at price  tensor([73.4160])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([70.4198])
# Predicted stock price for tomorrow:  tensor([70.3581])
# Day 850 : Sold  0 at price  tensor([70.4198])
# Current number of stocks:  0
# Current seed money: tensor([13179.4512])
# Today's stock price:  tensor([73.3492])
# Predicted stock price for tomorrow:  tensor([74.0278])
# Day 851 : Bought  tensor([179.6808]) stocks at price  tensor([73.3492])
# Predicted earnings:  tensor([50365.0586])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([72.7576])
# Predicted stock price for tomorrow:  tensor([74.7255])
# Day 852 : Bought  tensor([179.6808]) stocks at price  tensor([72.7576])
# Predicted earnings:  tensor([50718.6445])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([76.6317])
# Predicted stock price for tomorrow:  tensor([77.4663])
# Day 853 : Bought  tensor([179.6808]) stocks at price  tensor([76.6317])
# Predicted earnings:  tensor([50868.6172])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([74.9618])
# Predicted stock price for tomorrow:  tensor([78.4261])
# Day 854 : Bought  tensor([179.6808]) stocks at price  tensor([74.9618])
# Predicted earnings:  tensor([51491.0781])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([77.8817])
# Predicted stock price for tomorrow:  tensor([79.6600])
# Day 855 : Bought  tensor([179.6808]) stocks at price  tensor([77.8817])
# Predicted earnings:  tensor([51810.6016])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([78.7118])
# Predicted stock price for tomorrow:  tensor([79.3304])
# Day 856 : Bought  tensor([179.6808]) stocks at price  tensor([78.7118])
# Predicted earnings:  tensor([51921.7461])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([76.8511])
# Predicted stock price for tomorrow:  tensor([79.7838])
# Day 857 : Bought  tensor([179.6808]) stocks at price  tensor([76.8511])
# Predicted earnings:  tensor([52448.6836])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([79.0458])
# Predicted stock price for tomorrow:  tensor([79.5653])
# Day 858 : Bought  tensor([179.6808]) stocks at price  tensor([79.0458])
# Predicted earnings:  tensor([52542.0234])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([78.3111])
# Predicted stock price for tomorrow:  tensor([79.6557])
# Day 859 : Bought  tensor([179.6808]) stocks at price  tensor([78.3111])
# Predicted earnings:  tensor([52783.6289])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([79.1985])
# Predicted stock price for tomorrow:  tensor([80.3763])
# Day 860 : Bought  tensor([179.6808]) stocks at price  tensor([79.1985])
# Predicted earnings:  tensor([52995.2617])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([79.6374])
# Predicted stock price for tomorrow:  tensor([80.1425])
# Day 861 : Bought  tensor([179.6808]) stocks at price  tensor([79.6374])
# Predicted earnings:  tensor([53086.0195])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([79.2939])
# Predicted stock price for tomorrow:  tensor([80.7812])
# Day 862 : Bought  tensor([179.6808]) stocks at price  tensor([79.2939])
# Predicted earnings:  tensor([53353.2578])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([74.9618])
# Predicted stock price for tomorrow:  tensor([80.5753])
# Day 863 : Bought  tensor([179.6808]) stocks at price  tensor([74.9618])
# Predicted earnings:  tensor([54361.8906])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([76.3168])
# Predicted stock price for tomorrow:  tensor([79.6722])
# Day 864 : Bought  tensor([179.6808]) stocks at price  tensor([76.3168])
# Predicted earnings:  tensor([54964.7852])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([77.1756])
# Predicted stock price for tomorrow:  tensor([79.8346])
# Day 865 : Bought  tensor([179.6808]) stocks at price  tensor([77.1756])
# Predicted earnings:  tensor([55442.5547])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([77.7004])
# Predicted stock price for tomorrow:  tensor([80.4351])
# Day 866 : Bought  tensor([179.6808]) stocks at price  tensor([77.7004])
# Predicted earnings:  tensor([55933.9258])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([80.1336])
# Predicted stock price for tomorrow:  tensor([80.9610])
# Day 867 : Bought  tensor([179.6808]) stocks at price  tensor([80.1336])
# Predicted earnings:  tensor([56082.5938])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([77.4618])
# Predicted stock price for tomorrow:  tensor([80.4893])
# Day 868 : Bought  tensor([179.6808]) stocks at price  tensor([77.4618])
# Predicted earnings:  tensor([56626.5625])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([77.0706])
# Predicted stock price for tomorrow:  tensor([80.0446])
# Day 869 : Bought  tensor([179.6808]) stocks at price  tensor([77.0706])
# Predicted earnings:  tensor([57160.9336])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([75.7061])
# Predicted stock price for tomorrow:  tensor([79.1339])
# Day 870 : Bought  tensor([179.6808]) stocks at price  tensor([75.7061])
# Predicted earnings:  tensor([57776.8398])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([74.1126])
# Predicted stock price for tomorrow:  tensor([77.4455])
# Day 871 : Bought  tensor([179.6808]) stocks at price  tensor([74.1126])
# Predicted earnings:  tensor([58375.6992])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([73.3397])
# Predicted stock price for tomorrow:  tensor([76.3189])
# Day 872 : Bought  tensor([179.6808]) stocks at price  tensor([73.3397])
# Predicted earnings:  tensor([58911.0117])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([74.4370])
# Predicted stock price for tomorrow:  tensor([75.9733])
# Day 873 : Bought  tensor([179.6808]) stocks at price  tensor([74.4370])
# Predicted earnings:  tensor([59187.0586])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([73.5878])
# Predicted stock price for tomorrow:  tensor([75.8627])
# Day 874 : Bought  tensor([179.6808]) stocks at price  tensor([73.5878])
# Predicted earnings:  tensor([59595.8242])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([72.1374])
# Predicted stock price for tomorrow:  tensor([74.9301])
# Day 875 : Bought  tensor([179.6808]) stocks at price  tensor([72.1374])
# Predicted earnings:  tensor([60097.6094])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([72.9008])
# Predicted stock price for tomorrow:  tensor([74.3546])
# Day 876 : Bought  tensor([179.6808]) stocks at price  tensor([72.9008])
# Predicted earnings:  tensor([60358.8320])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([74.3416])
# Predicted stock price for tomorrow:  tensor([74.5288])
# Day 877 : Bought  tensor([179.6808]) stocks at price  tensor([74.3416])
# Predicted earnings:  tensor([60392.4648])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([73.6546])
# Predicted stock price for tomorrow:  tensor([74.0796])
# Day 878 : Bought  tensor([179.6808]) stocks at price  tensor([73.6546])
# Predicted earnings:  tensor([60468.8320])
# Current number of stocks:  tensor([179.6808])
# Current seed money: 0
# Today's stock price:  tensor([74.3225])
# Predicted stock price for tomorrow:  tensor([74.1407])
# Day 879 : Sold  tensor([179.6808]) at price  tensor([74.3225])
# Current number of stocks:  0
# Current seed money: tensor([13354.3320])
# Today's stock price:  tensor([76.3836])
# Predicted stock price for tomorrow:  tensor([74.0881])
# Day 880 : Sold  0 at price  tensor([76.3836])
# Current number of stocks:  0
# Current seed money: tensor([13354.3320])
# Today's stock price:  tensor([76.1260])
# Predicted stock price for tomorrow:  tensor([74.1347])
# Day 881 : Sold  0 at price  tensor([76.1260])
# Current number of stocks:  0
# Current seed money: tensor([13354.3320])
# Today's stock price:  tensor([76.0687])
# Predicted stock price for tomorrow:  tensor([74.2126])
# Day 882 : Sold  0 at price  tensor([76.0687])
# Current number of stocks:  0
# Current seed money: tensor([13354.3320])
# Today's stock price:  tensor([73.9981])
# Predicted stock price for tomorrow:  tensor([74.1536])
# Day 883 : Bought  tensor([180.4686]) stocks at price  tensor([73.9981])
# Predicted earnings:  tensor([60496.8984])
# Current number of stocks:  tensor([180.4686])
# Current seed money: 0
# Today's stock price:  tensor([73.3683])
# Predicted stock price for tomorrow:  tensor([74.0906])
# Day 884 : Bought  tensor([180.4686]) stocks at price  tensor([73.3683])
# Predicted earnings:  tensor([60627.2422])
# Current number of stocks:  tensor([180.4686])
# Current seed money: 0
# Today's stock price:  tensor([73.0439])
# Predicted stock price for tomorrow:  tensor([73.8010])
# Day 885 : Bought  tensor([180.4686]) stocks at price  tensor([73.0439])
# Predicted earnings:  tensor([60763.8711])
# Current number of stocks:  tensor([180.4686])
# Current seed money: 0
# Today's stock price:  tensor([72.8721])
# Predicted stock price for tomorrow:  tensor([73.4111])
# Day 886 : Bought  tensor([180.4686]) stocks at price  tensor([72.8721])
# Predicted earnings:  tensor([60861.1406])
# Current number of stocks:  tensor([180.4686])
# Current seed money: 0
# Today's stock price:  tensor([73.7214])
# Predicted stock price for tomorrow:  tensor([73.5212])
# Day 887 : Sold  tensor([180.4686]) at price  tensor([73.7214])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([73.9981])
# Predicted stock price for tomorrow:  tensor([73.2888])
# Day 888 : Sold  0 at price  tensor([73.9981])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([75.4198])
# Predicted stock price for tomorrow:  tensor([73.9852])
# Day 889 : Sold  0 at price  tensor([75.4198])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([77.0229])
# Predicted stock price for tomorrow:  tensor([74.4170])
# Day 890 : Sold  0 at price  tensor([77.0229])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([75.9160])
# Predicted stock price for tomorrow:  tensor([74.6975])
# Day 891 : Sold  0 at price  tensor([75.9160])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([77.1374])
# Predicted stock price for tomorrow:  tensor([75.0175])
# Day 892 : Sold  0 at price  tensor([77.1374])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([78.3015])
# Predicted stock price for tomorrow:  tensor([75.2251])
# Day 893 : Sold  0 at price  tensor([78.3015])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([77.8149])
# Predicted stock price for tomorrow:  tensor([75.4727])
# Day 894 : Sold  0 at price  tensor([77.8149])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([78.4924])
# Predicted stock price for tomorrow:  tensor([75.9268])
# Day 895 : Sold  0 at price  tensor([78.4924])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([79.1031])
# Predicted stock price for tomorrow:  tensor([75.9256])
# Day 896 : Sold  0 at price  tensor([79.1031])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Today's stock price:  tensor([78.4924])
# Predicted stock price for tomorrow:  tensor([76.1872])
# Day 897 : Sold  0 at price  tensor([78.4924])
# Current number of stocks:  0
# Current seed money: tensor([13304.3926])
# Trading earnings: tensor([13304.3926])
# Predicted earnings: tensor([60861.1406])

# %%
pred_output
# Out:
# [tensor([60.2619]),
#  tensor([61.0186]),
#  tensor([60.8270]),
#  tensor([60.5377]),
#  tensor([60.0871]),
#  tensor([59.9112]),
#  tensor([60.0275]),
#  tensor([59.5807]),
#  tensor([59.4172]),
#  tensor([59.3974]),
#  tensor([59.2566]),
#  tensor([58.6367]),
#  tensor([58.0160]),
#  tensor([57.7869]),
#  tensor([57.5544]),
#  tensor([57.1688]),
#  tensor([57.1063]),
#  tensor([56.5995]),
#  tensor([57.2241]),
#  tensor([57.7395]),
#  tensor([57.9233]),
#  tensor([57.8267]),
#  tensor([58.2079]),
#  tensor([58.8353]),
#  tensor([58.4845]),
#  tensor([58.0714]),
#  tensor([57.2829]),
#  tensor([56.9962]),
#  tensor([57.0892]),
#  tensor([57.1859]),
#  tensor([56.8465]),
#  tensor([56.7661]),
#  tensor([56.6135]),
#  tensor([57.0714]),
#  tensor([57.2653]),
#  tensor([57.3900]),
#  tensor([57.3538]),
#  tensor([57.8917]),
#  tensor([57.8168]),
#  tensor([58.4645]),
#  tensor([59.0793]),
#  tensor([59.4178]),
#  tensor([59.1815]),
#  tensor([58.7201]),
#  tensor([58.3021]),
#  tensor([59.1154]),
#  tensor([59.3373]),
#  tensor([58.9961]),
#  tensor([58.8400]),
#  tensor([58.7645]),
#  tensor([58.8938]),
#  tensor([58.7491]),
#  tensor([58.8664]),
#  tensor([59.0678]),
#  tensor([60.1586]),
#  tensor([60.5851]),
#  tensor([60.8716]),
#  tensor([60.8216]),
#  tensor([60.7653]),
#  tensor([60.9194]),
#  tensor([61.0329]),
#  tensor([61.2311]),
#  tensor([62.2071]),
#  tensor([62.6842]),
#  tensor([62.3277]),
#  tensor([62.3634]),
#  tensor([62.4627]),
#  tensor([62.4480]),
#  tensor([62.8871]),
#  tensor([63.0164]),
#  tensor([62.8158]),
#  tensor([62.8771]),
#  tensor([63.1091]),
#  tensor([63.0088]),
#  tensor([63.1883]),
#  tensor([63.2341]),
#  tensor([63.1183]),
#  tensor([63.1095]),
#  tensor([62.9920]),
#  tensor([63.1022]),
#  tensor([62.6758]),
#  tensor([62.0173]),
#  tensor([62.1546]),
#  tensor([62.1486]),
#  tensor([61.8725]),
#  tensor([61.6830]),
#  tensor([61.4210]),
#  tensor([61.0844]),
#  tensor([60.7755]),
#  tensor([60.6842]),
#  tensor([60.5173]),
#  tensor([60.4112]),
#  tensor([60.3003]),
#  tensor([60.2010]),
#  tensor([60.1808]),
#  tensor([59.8882]),
#  tensor([60.2778]),
#  tensor([60.0539]),
#  tensor([59.9054]),
#  tensor([59.8243]),
#  tensor([59.6423]),
#  tensor([59.4905]),
#  tensor([59.3893]),
#  tensor([59.4256]),
#  tensor([59.5375]),
#  tensor([59.3243]),
#  tensor([59.3781]),
#  tensor([59.5183]),
#  tensor([59.2135]),
#  tensor([59.3317]),
#  tensor([59.6331]),
#  tensor([59.6909]),
#  tensor([59.7192]),
#  tensor([59.6647]),
#  tensor([59.7453]),
#  tensor([60.0159]),
#  tensor([60.2567]),
#  tensor([60.3692]),
#  tensor([60.7540]),
#  tensor([60.8410]),
#  tensor([60.7857]),
#  tensor([60.9324]),
#  tensor([61.2004]),
#  tensor([61.0065]),
#  tensor([61.1046]),
#  tensor([60.8589]),
#  tensor([60.6029]),
#  tensor([60.6217]),
#  tensor([60.8215]),
#  tensor([61.0316]),
#  tensor([61.1638]),
#  tensor([61.3576]),
#  tensor([61.5455]),
#  tensor([61.5933]),
#  tensor([61.9288]),
#  tensor([61.9260]),
#  tensor([61.9874]),
#  tensor([62.2179]),
#  tensor([62.2477]),
#  tensor([62.0937]),
#  tensor([61.9095]),
#  tensor([61.6772]),
#  tensor([61.6068]),
#  tensor([62.0479]),
#  tensor([61.6138]),
#  tensor([61.1225]),
#  tensor([60.9357]),
#  tensor([60.8389]),
#  tensor([60.7591]),
#  tensor([61.0406]),
#  tensor([61.5631]),
#  tensor([61.9159]),
#  tensor([61.9737]),
#  tensor([62.0323]),
#  tensor([62.1692]),
#  tensor([61.9803]),
#  tensor([61.6815]),
#  tensor([61.2455]),
#  tensor([61.3154]),
#  tensor([61.2406]),
#  tensor([61.2392]),
#  tensor([60.6298]),
#  tensor([60.4695]),
#  tensor([60.1196]),
#  tensor([60.2381]),
#  tensor([60.3402]),
#  tensor([60.3662]),
#  tensor([60.0918]),
#  tensor([59.8432]),
#  tensor([59.7272]),
#  tensor([60.1267]),
#  tensor([59.9227]),
#  tensor([59.8168]),
#  tensor([59.6211]),
#  tensor([59.2570]),
#  tensor([59.9825]),
#  tensor([60.5184]),
#  tensor([60.5841]),
#  tensor([60.5051]),
#  tensor([60.3634]),
#  tensor([60.1881]),
#  tensor([60.0451]),
#  tensor([59.9297]),
#  tensor([59.8423]),
#  tensor([59.5828]),
#  tensor([59.3218]),
#  tensor([59.2699]),
#  tensor([59.6450]),
#  tensor([59.7293]),
#  tensor([59.4318]),
#  tensor([59.3419]),
#  tensor([58.8625]),
#  tensor([58.9458]),
#  tensor([59.1580]),
#  tensor([59.1757]),
#  tensor([59.3691]),
#  tensor([59.5498]),
#  tensor([59.8565]),
#  tensor([59.9252]),
#  tensor([60.2563]),
#  tensor([60.0421]),
#  tensor([60.3325]),
#  tensor([60.4817]),
#  tensor([60.7851]),
#  tensor([60.8464]),
#  tensor([61.0835]),
#  tensor([61.5178]),
#  tensor([61.7825]),
#  tensor([61.7635]),
#  tensor([62.0489]),
#  tensor([62.3640]),
#  tensor([62.4264]),
#  tensor([62.5474]),
#  tensor([62.6788]),
#  tensor([62.8584]),
#  tensor([62.8576]),
#  tensor([62.6512]),
#  tensor([62.6276]),
#  tensor([62.5202]),
#  tensor([62.3915]),
#  tensor([62.4893]),
#  tensor([62.5017]),
#  tensor([62.2315]),
#  tensor([62.2584]),
#  tensor([62.1726]),
#  tensor([62.2501]),
#  tensor([62.1145]),
#  tensor([62.0103]),
#  tensor([61.8029]),
#  tensor([61.3012]),
#  tensor([61.3142]),
#  tensor([61.0894]),
#  tensor([60.6599]),
#  tensor([60.8539]),
#  tensor([60.8320]),
#  tensor([60.5484]),
#  tensor([60.5324]),
#  tensor([59.9654]),
#  tensor([59.6495]),
#  tensor([59.0568]),
#  tensor([57.7321]),
#  tensor([53.5692]),
#  tensor([52.8721]),
#  tensor([52.9207]),
#  tensor([52.4725]),
#  tensor([52.7080]),
#  tensor([52.5987]),
#  tensor([52.3085]),
#  tensor([52.6180]),
#  tensor([52.0324]),
#  tensor([53.0234]),
#  tensor([51.8112]),
#  tensor([52.4128]),
#  tensor([51.8963]),
#  tensor([52.0014]),
#  tensor([51.6564]),
#  tensor([52.4809]),
#  tensor([51.9356]),
#  tensor([52.1780]),
#  tensor([52.1202]),
#  tensor([52.2343]),
#  tensor([52.2917]),
#  tensor([52.6419]),
#  tensor([52.5363]),
#  tensor([52.8479]),
#  tensor([53.0992]),
#  tensor([52.9329]),
#  tensor([52.5034]),
#  tensor([52.0694]),
#  tensor([52.4534]),
#  tensor([53.1127]),
#  tensor([53.9691]),
#  tensor([54.1577]),
#  tensor([54.2382]),
#  tensor([53.6701]),
#  tensor([53.4365]),
#  tensor([53.7020]),
#  tensor([53.7487]),
#  tensor([54.2138]),
#  tensor([54.1871]),
#  tensor([54.3600]),
#  tensor([54.1147]),
#  tensor([53.7931]),
#  tensor([53.8746]),
#  tensor([53.9882]),
#  tensor([53.7765]),
#  tensor([53.8440]),
#  tensor([54.7409]),
#  tensor([54.5981]),
#  tensor([53.7064]),
#  tensor([54.1375]),
#  tensor([54.5167]),
#  tensor([55.2373]),
#  tensor([56.8737]),
#  tensor([56.8104]),
#  tensor([56.8128]),
#  tensor([57.4884]),
#  tensor([57.3136]),
#  tensor([57.5437]),
#  tensor([57.6466]),
#  tensor([57.5740]),
#  tensor([58.0469]),
#  tensor([58.4323]),
#  tensor([58.3559]),
#  tensor([57.8441]),
#  tensor([57.5880]),
#  tensor([57.7266]),
#  tensor([56.4390]),
#  tensor([55.3196]),
#  tensor([54.7426]),
#  tensor([53.3199]),
#  tensor([53.9160]),
#  tensor([53.6276]),
#  tensor([53.3405]),
#  tensor([52.5653]),
#  tensor([53.5955]),
#  tensor([53.4324]),
#  tensor([52.3138]),
#  tensor([52.2225]),
#  tensor([51.8108]),
#  tensor([51.7981]),
#  tensor([52.4381]),
#  tensor([52.0028]),
#  tensor([51.7278]),
#  tensor([51.4754]),
#  tensor([51.6961]),
#  tensor([52.0085]),
#  tensor([52.1034]),
#  tensor([52.1287]),
#  tensor([52.4602]),
#  tensor([52.3378]),
#  tensor([52.8451]),
#  tensor([52.8452]),
#  tensor([52.6748]),
#  tensor([52.5152]),
#  tensor([52.8648]),
#  tensor([52.4402]),
#  tensor([52.3240]),
#  tensor([52.3465]),
#  tensor([52.0143]),
#  tensor([51.7656]),
#  tensor([51.9172]),
#  tensor([51.6188]),
#  tensor([52.0659]),
#  tensor([52.1084]),
#  tensor([51.4359]),
#  tensor([51.4860]),
#  tensor([51.8455]),
#  tensor([51.9623]),
#  tensor([51.3477]),
#  tensor([52.2020]),
#  tensor([53.0384]),
#  tensor([53.1171]),
#  tensor([53.3405]),
#  tensor([53.7772]),
#  tensor([55.3423]),
#  tensor([56.0465]),
#  tensor([55.6520]),
#  tensor([55.4450]),
#  tensor([55.4838]),
#  tensor([56.6801]),
#  tensor([56.5035]),
#  tensor([56.3428]),
#  tensor([56.5940]),
#  tensor([56.7870]),
#  tensor([56.7133]),
#  tensor([56.2567]),
#  tensor([55.5150]),
#  tensor([55.8467]),
#  tensor([55.8621]),
#  tensor([55.6727]),
#  tensor([55.7448]),
#  tensor([55.7420]),
#  tensor([55.8446]),
#  tensor([56.5576]),
#  tensor([57.2287]),
#  tensor([57.0380]),
#  tensor([57.0190]),
#  tensor([57.1327]),
#  tensor([57.0832]),
#  tensor([56.4131]),
#  tensor([56.3396]),
#  tensor([56.8381]),
#  tensor([56.3875]),
#  tensor([56.3869]),
#  tensor([56.0663]),
#  tensor([56.7013]),
#  tensor([56.8677]),
#  tensor([56.9478]),
#  tensor([58.0453]),
#  tensor([57.7679]),
#  tensor([57.6433]),
#  tensor([57.9482]),
#  tensor([58.3229]),
#  tensor([58.4037]),
#  tensor([58.9475]),
#  tensor([59.0744]),
#  tensor([58.7417]),
#  tensor([58.6792]),
#  tensor([58.4889]),
#  tensor([58.1995]),
#  tensor([58.4337]),
#  tensor([58.5453]),
#  tensor([58.7884]),
#  tensor([58.8565]),
#  tensor([58.4752]),
#  tensor([58.7022]),
#  tensor([58.0510]),
#  tensor([58.7119]),
#  tensor([58.5773]),
#  tensor([58.5383]),
#  tensor([58.9011]),
#  tensor([59.1779]),
#  tensor([59.4699]),
#  tensor([59.3919]),
#  tensor([59.2693]),
#  tensor([59.5376]),
#  tensor([59.5576]),
#  tensor([59.5286]),
#  tensor([59.5154]),
#  tensor([59.6138]),
#  tensor([59.8725]),
#  tensor([59.6383]),
#  tensor([59.6129]),
#  tensor([59.9605]),
#  tensor([60.3575]),
#  tensor([60.5548]),
#  tensor([60.4716]),
#  tensor([60.8653]),
#  tensor([61.4487]),
#  tensor([61.5031]),
#  tensor([61.5797]),
#  tensor([61.8661]),
#  tensor([62.0941]),
#  tensor([62.5124]),
#  tensor([62.8382]),
#  tensor([62.7812]),
#  tensor([62.7335]),
#  tensor([63.0221]),
#  tensor([63.2313]),
#  tensor([64.0622]),
#  tensor([64.7151]),
#  tensor([64.8802]),
#  tensor([65.5005]),
#  tensor([65.5437]),
#  tensor([65.4974]),
#  tensor([65.6449]),
#  tensor([65.7906]),
#  tensor([65.9855]),
#  tensor([66.0356]),
#  tensor([66.1054]),
#  tensor([66.2526]),
#  tensor([66.3113]),
#  tensor([66.2377]),
#  tensor([66.3663]),
#  tensor([66.3441]),
#  tensor([66.6367]),
#  tensor([66.5625]),
#  tensor([66.2533]),
#  tensor([66.2409]),
#  tensor([66.4548]),
#  tensor([66.6152]),
#  tensor([66.6424]),
#  tensor([66.5289]),
#  tensor([66.5327]),
#  tensor([66.8580]),
#  tensor([67.3560]),
#  tensor([67.1676]),
#  tensor([66.9851]),
#  tensor([67.0115]),
#  tensor([66.9487]),
#  tensor([67.0506]),
#  tensor([67.2393]),
#  tensor([67.7365]),
#  tensor([67.8132]),
#  tensor([67.9048]),
#  tensor([67.6695]),
#  tensor([67.6474]),
#  tensor([67.7616]),
#  tensor([67.9621]),
#  tensor([67.4211]),
#  tensor([67.2340]),
#  tensor([67.2582]),
#  tensor([67.6430]),
#  tensor([67.2337]),
#  tensor([68.1541]),
#  tensor([68.2399]),
#  tensor([68.6147]),
#  tensor([68.6884]),
#  tensor([68.2437]),
#  tensor([68.3149]),
#  tensor([67.6842]),
#  tensor([68.2075]),
#  tensor([68.7397]),
#  tensor([69.0433]),
#  tensor([69.2104]),
#  tensor([68.8293]),
#  tensor([68.9035]),
#  tensor([68.9877]),
#  tensor([69.7054]),
#  tensor([70.2887]),
#  tensor([70.5499]),
#  tensor([70.6466]),
#  tensor([70.6446]),
#  tensor([70.6232]),
#  tensor([70.9040]),
#  tensor([71.1064]),
#  tensor([71.5921]),
#  tensor([71.5041]),
#  tensor([71.1602]),
#  tensor([70.9043]),
#  tensor([71.1479]),
#  tensor([71.4129]),
#  tensor([72.0064]),
#  tensor([72.3751]),
#  tensor([73.0293]),
#  tensor([73.0308]),
#  tensor([73.3584]),
#  tensor([73.5885]),
#  tensor([73.2652]),
#  tensor([73.4805]),
#  tensor([73.6716]),
#  tensor([73.8315]),
#  tensor([73.8869]),
#  tensor([73.8091]),
#  tensor([73.5879]),
#  tensor([73.1286]),
#  tensor([73.0118]),
#  tensor([72.6903]),
#  tensor([70.7543]),
#  tensor([70.8268]),
#  tensor([71.1789]),
#  tensor([71.6924]),
#  tensor([71.8965]),
#  tensor([72.1832]),
#  tensor([72.2296]),
#  tensor([71.7523]),
#  tensor([72.1262]),
#  tensor([72.3230]),
#  tensor([72.3990]),
#  tensor([70.9442]),
#  tensor([72.3318]),
#  tensor([71.9520]),
#  tensor([71.2607]),
#  tensor([71.5235]),
#  tensor([71.5181]),
#  tensor([71.6924]),
#  tensor([71.9189]),
#  tensor([71.8374]),
#  tensor([70.8280]),
#  tensor([70.0702]),
#  tensor([70.8644]),
#  tensor([70.5061]),
#  tensor([70.4737]),
#  tensor([70.5408]),
#  tensor([70.8206]),
#  tensor([71.4226]),
#  tensor([71.9374]),
#  tensor([72.3691]),
#  tensor([71.7851]),
#  tensor([72.6447]),
#  tensor([72.8038]),
#  tensor([73.0439]),
#  tensor([73.2809]),
#  tensor([73.6033]),
#  tensor([73.8719]),
#  tensor([74.4006]),
#  tensor([74.5126]),
#  tensor([74.7347]),
#  tensor([74.8300]),
#  tensor([75.0880]),
#  tensor([75.2463]),
#  tensor([75.4163]),
#  tensor([75.3728]),
#  tensor([75.2047]),
#  tensor([75.7720]),
#  tensor([75.8358]),
#  tensor([75.8986]),
#  tensor([75.9704]),
#  tensor([75.9863]),
#  tensor([75.8748]),
#  tensor([75.9181]),
#  tensor([75.9517]),
#  tensor([76.0813]),
#  tensor([76.4269]),
#  tensor([76.6728]),
#  tensor([76.6833]),
#  tensor([76.7106]),
#  tensor([76.9861]),
#  tensor([77.0681]),
#  tensor([77.3826]),
#  tensor([77.4615]),
#  tensor([77.5916]),
#  tensor([77.8303]),
#  tensor([77.7414]),
#  tensor([78.1310]),
#  tensor([78.3811]),
#  tensor([78.4710]),
#  tensor([78.4400]),
#  tensor([78.5612]),
#  tensor([78.4029]),
#  tensor([78.3706]),
#  tensor([78.3193]),
#  tensor([78.4860]),
#  tensor([78.4690]),
#  tensor([78.3902]),
#  tensor([78.2457]),
#  tensor([77.5702]),
#  tensor([75.0314]),
#  tensor([73.3015]),
#  tensor([75.0909]),
#  tensor([74.9840]),
#  tensor([74.4140]),
#  tensor([74.6462]),
#  tensor([72.9163]),
#  tensor([74.9289]),
#  tensor([74.7762]),
#  tensor([75.7261]),
#  tensor([75.9723]),
#  tensor([76.1057]),
#  tensor([76.0428]),
#  tensor([75.5229]),
#  tensor([75.6608]),
#  tensor([75.3537]),
#  tensor([72.9959]),
#  tensor([74.7244]),
#  tensor([74.5261]),
#  tensor([74.5320]),
#  tensor([74.9611]),
#  tensor([74.9519]),
#  tensor([74.3698]),
#  tensor([74.8809]),
#  tensor([75.3284]),
#  tensor([75.5714]),
#  tensor([75.7271]),
#  tensor([75.6948]),
#  tensor([75.4369]),
#  tensor([75.3912]),
#  tensor([75.1252]),
#  tensor([75.3898]),
#  tensor([75.7153]),
#  tensor([76.1145]),
#  tensor([76.2835]),
#  tensor([76.5575]),
#  tensor([76.9120]),
#  tensor([77.1253]),
#  tensor([77.3095]),
#  tensor([77.4327]),
#  tensor([77.4970]),
#  tensor([77.6195]),
#  tensor([77.9391]),
#  tensor([78.1472]),
#  tensor([78.3793]),
#  tensor([78.5307]),
#  tensor([78.5507]),
#  tensor([78.9127]),
#  tensor([78.6855]),
#  tensor([78.7203]),
#  tensor([78.6043]),
#  tensor([78.7616]),
#  tensor([79.1131]),
#  tensor([79.3664]),
#  tensor([79.4444]),
#  tensor([79.0403]),
#  tensor([79.5042]),
#  tensor([79.5641]),
#  tensor([78.7700]),
#  tensor([78.3260]),
#  tensor([77.6798]),
#  tensor([78.9273]),
#  tensor([78.7782]),
#  tensor([79.2105]),
#  tensor([79.0862]),
#  tensor([78.9199]),
#  tensor([79.0609]),
#  tensor([79.1355]),
#  tensor([79.0533]),
#  tensor([78.9780]),
#  tensor([79.1426]),
#  tensor([79.2688]),
#  tensor([79.3193]),
#  tensor([79.3354]),
#  tensor([79.4557]),
#  tensor([79.3995]),
#  tensor([79.4826]),
#  tensor([79.5208]),
#  tensor([79.6823]),
#  tensor([79.8225]),
#  tensor([79.8863]),
#  tensor([80.1390]),
#  tensor([79.9893]),
#  tensor([79.7867]),
#  tensor([79.8737]),
#  tensor([80.1644]),
#  tensor([80.2084]),
#  tensor([80.4653]),
#  tensor([80.5625]),
#  tensor([80.3771]),
#  tensor([80.4022]),
#  tensor([80.4613]),
#  tensor([80.5621]),
#  tensor([80.6864]),
#  tensor([80.8568]),
#  tensor([80.8692]),
#  tensor([80.9894]),
#  tensor([81.0038]),
#  tensor([81.0833]),
#  tensor([80.8880]),
#  tensor([79.3443]),
#  tensor([80.4993]),
#  tensor([80.5591]),
#  tensor([80.5978]),
#  tensor([80.3639]),
#  tensor([80.1127]),
#  tensor([80.2937]),
#  tensor([80.4750]),
#  tensor([80.3907]),
#  tensor([80.7233]),
#  tensor([80.6716]),
#  tensor([80.5483]),
#  tensor([80.5216]),
#  tensor([80.4308]),
#  tensor([80.5022]),
#  tensor([80.4225]),
#  tensor([79.5109]),
#  tensor([79.8147]),
#  tensor([80.1982]),
#  tensor([80.3365]),
#  tensor([79.4746]),
#  tensor([80.0637]),
#  tensor([80.1799]),
#  tensor([80.1653]),
#  tensor([80.3394]),
#  tensor([80.5193]),
#  tensor([80.5210]),
#  tensor([80.4486]),
#  tensor([80.1630]),
#  tensor([80.4451]),
#  tensor([79.9219]),
#  tensor([80.0148]),
#  tensor([80.0126]),
#  tensor([79.9319]),
#  tensor([79.3469]),
#  tensor([80.0047]),
#  tensor([80.3290]),
#  tensor([80.6947]),
#  tensor([80.7257]),
#  tensor([80.6226]),
#  tensor([80.4678]),
#  tensor([80.4116]),
#  tensor([80.3614]),
#  tensor([80.3605]),
#  tensor([80.2957]),
#  tensor([80.3410]),
#  tensor([80.4761]),
#  tensor([80.5533]),
#  tensor([80.6257]),
#  tensor([80.6325]),
#  tensor([80.5497]),
#  tensor([80.6278]),
#  tensor([80.6146]),
#  tensor([80.6987]),
#  tensor([80.7024]),
#  tensor([81.0006]),
#  tensor([81.0831]),
#  tensor([80.9367]),
#  tensor([81.2280]),
#  tensor([81.2801]),
#  tensor([81.4692]),
#  tensor([81.6539]),
#  tensor([81.7703]),
#  tensor([81.8530]),
#  tensor([81.9136]),
#  tensor([82.0453]),
#  tensor([82.1487]),
#  tensor([82.2324]),
#  tensor([82.2619]),
#  tensor([82.4362]),
#  tensor([82.5587]),
#  tensor([82.6439]),
#  tensor([82.8368]),
#  tensor([82.9090]),
#  tensor([82.9926]),
#  tensor([83.1201]),
#  tensor([83.2888]),
#  tensor([83.4441]),
#  tensor([83.4850]),
#  tensor([83.6919]),
#  tensor([83.7433]),
#  tensor([83.9602]),
#  tensor([84.0341]),
#  tensor([84.0701]),
#  tensor([84.1456]),
#  tensor([84.2303]),
#  tensor([84.3429]),
#  tensor([84.3705]),
#  tensor([84.4847]),
#  tensor([84.6047]),
#  tensor([84.7723]),
#  tensor([84.8527]),
#  tensor([84.8672]),
#  tensor([84.9507]),
#  tensor([84.8718]),
#  tensor([84.7488]),
#  tensor([84.7220]),
#  tensor([84.4745]),
#  tensor([84.6580]),
#  tensor([84.3320]),
#  tensor([84.5663]),
#  tensor([84.6554]),
#  tensor([84.6531]),
#  tensor([84.4941]),
#  tensor([84.2823]),
#  tensor([84.3230]),
#  tensor([84.2450]),
#  tensor([84.0716]),
#  tensor([83.4788]),
#  tensor([83.1225]),
#  tensor([82.7538]),
#  tensor([82.7209]),
#  tensor([82.3207]),
#  tensor([81.9544]),
#  tensor([80.9501]),
#  tensor([79.8808]),
#  tensor([78.9966]),
#  tensor([77.7990]),
#  tensor([71.1260]),
#  tensor([76.5325]),
#  tensor([76.2438]),
#  tensor([77.7184]),
#  tensor([78.1288]),
#  tensor([78.2120]),
#  tensor([77.0544]),
#  tensor([77.8499]),
#  tensor([75.1526]),
#  tensor([70.7335]),
#  tensor([69.8359]),
#  tensor([65.1084]),
#  tensor([68.0429]),
#  tensor([66.7207]),
#  tensor([65.4139]),
#  tensor([64.6214]),
#  tensor([60.6657]),
#  tensor([61.5860]),
#  tensor([61.9029]),
#  tensor([65.4000]),
#  tensor([65.0961]),
#  tensor([70.4044]),
#  tensor([72.5632]),
#  tensor([70.3581]),
#  tensor([74.0278]),
#  tensor([74.7255]),
#  tensor([77.4663]),
#  tensor([78.4261]),
#  tensor([79.6600]),
#  tensor([79.3304]),
#  tensor([79.7838]),
#  tensor([79.5653]),
#  tensor([79.6557]),
#  tensor([80.3763]),
#  tensor([80.1425]),
#  tensor([80.7812]),
#  tensor([80.5753]),
#  tensor([79.6722]),
#  tensor([79.8346]),
#  tensor([80.4351]),
#  tensor([80.9610]),
#  tensor([80.4893]),
#  tensor([80.0446]),
#  tensor([79.1339]),
#  tensor([77.4455]),
#  tensor([76.3189]),
#  tensor([75.9733]),
#  tensor([75.8627]),
#  tensor([74.9301]),
#  tensor([74.3546]),
#  tensor([74.5288]),
#  tensor([74.0796]),
#  tensor([74.1407]),
#  tensor([74.0881]),
#  tensor([74.1347]),
#  tensor([74.2126]),
#  tensor([74.1536]),
#  tensor([74.0906]),
#  tensor([73.8010]),
#  tensor([73.4111]),
#  tensor([73.5212]),
#  tensor([73.2888]),
#  tensor([73.9852]),
#  tensor([74.4170]),
#  tensor([74.6975]),
#  tensor([75.0175]),
#  tensor([75.2251]),
#  tensor([75.4727]),
#  tensor([75.9268]),
#  tensor([75.9256]),
#  tensor([76.1872])]

# %%
plt.figure(figsize=(12, 7))
plt.plot(range(len(df_out)), df_out["Close_lead1"], label = "Real")
plt.plot(range(size, len(df_out)), pred_output, label = "LSTM Trading Strategy Prediction")
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.vlines(size, ymin = 30, ymax = 90, label = "Test set start", linestyles = "dashed")
plt.legend()
plt.show()
# Out:
# C:\Users\jonas\Anaconda3\envs\qrnn\lib\site-packages\numpy\core\shape_base.py:65: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   ary = asanyarray(ary)
# C:\Users\jonas\Anaconda3\envs\qrnn\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
import csv

# %%
with open('test.csv', 'a', newline='') as test_csv:
    test_csv_writer = csv.writer(test_csv)
    test_csv_writer.writerow(classical_loss_test)

# %%
with open('train.csv', 'a', newline='') as train_csv:
    train_csv_writer = csv.writer(train_csv)
    train_csv_writer.writerow(classical_loss_train)

# %%
with open('pred.csv', 'a', newline='') as pred_csv:
    pred_csv_writer = csv.writer(pred_csv)
    pred_csv_writer.writerow(df_out["Model forecast"])

# %%
for i in range(len(classical_loss_test)):
    writer.add_scalar("Test loss",classical_loss_test[i], i)
    
for i in range(len(classical_loss_train)):
    writer.add_scalar("Train loss: ", classical_loss_train[i], i)
    
for i in range(len(df_out["Model forecast"])):
    writer.add_scalar("Predicted Value: ", df_out["Model forecast"][i], i)
    
writer.close()

# %% [markdown]
# ## Number of parameters used

# %%
def count_parameters(m):
    return sum(p.numel() for p in m.parameters() if p.requires_grad)

# %%
count_parameters(model)

# %% [markdown]
# ## Complexity analysis

# %% [markdown]
# As a last point of comparison, we want to discuss the complexity analysis for the QLSTM, as well as compare the number of parameters used for the LSTM and the QLSTM.
#
# Given that we would want to eventually use the QLSTM on real quantum computers, it would be prudent to discuss its viability in terms of the number of gates and qubits used. First of all, we look at the number of qubits. As can be seen, in a barebones early version of QLSTM, we can afford to use any number of qubits, even a small number like 4 to run it. This is because we can sandwich it between two classical layers, where the classical layers help to convert the vector sizes to the correct amount, from the embedding of input features into the quantum circuit to the processing of the output measurements. This is very similar in idea to dressed quantum circuits, which was presented in:
#
# Transfer learning in hybrid classical-quantum neural networks: https://arxiv.org/abs/1912.08278, Andrea Mari, Thomas R. Bromley, Josh Izaac, Maria Schuld, Nathan Killoran
#
# In the foreseeable future in the NISQ era, we would likely be continuing to use the same technique, although the number of qubits can be increased to improve the model, making this technique useful in the NISQ era.
#
# For the number of gates used per circuit, we take a look at how the overall depth would increase as number of qubits and number of layers increases. As seen from the circuit above, the overall depth is $3 + n_l * (2 * n_q + 3)$, where $n_l, n_q$ refers to the number of layers and number of qubits respectively. Thus, the overall depth would increase linearly in both number of qubits and number of layers. What this also means is that the depth is quite easy to control, and extremely viable for the NISQ era. In this particular proof of example, we show that even when the number of layers is 1 (the smallest it can be) and the number of qubits is a small number, we still get pretty good results.

# %% [markdown]
# # Conclusion and Future Outlook

# %% [markdown]
# In this notebook, we have given the proof of concept that QLSTM can be used to great effect for stock price prediction, offering comparable results than its classical counterpart, while needed much fewer parameters to train and getting more information per epoch. All in all, this shows that this technique has a lot of potential in the financial world and more, as anything time series related can be trained using an LSTM and hence also a QLSTM. This is relevant not only to stock price predictions, but also for example company sales predictions or other key performance predictions. However, there are still many areas for improvement.
