# %%
#import helper
import pandas as pd
#from utils import *

import time
import numpy as np
import math
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader, Dataset
from torch import nn

from sklearn.decomposition import PCA

from IPython.display import Image

import pennylane as qml

# %% [markdown]
# # Introduction

# %% [markdown]
# Stock price prediction is one of the most rewarding problems in modern finance, where the accurate forecasting of future stock prices can yield significant profit and reduce the risks. LSTM (Long Short-Term Memory) is a recurrent Neural Network (RNN) applicable to a broad range of problems aiming to analyze or classify sequential data. Therefore, many people have used LSTM to predict the future stock price based on the historical data sequences with great success.
#
# On the other hand, recent studies have shown that the LSTM's efficiency and trainability can be improved by replacing some of the layers in the LSTM with variational quantum layers, thus making it a quantum-classical hybrid model of LSTM which we will call QLSTM for Quantum LSTM. In the study done by Samuel Yen-Chi Chen, Shinjae Yoo, and Yao-Lung L. Fang, they show that QLSTM offers better trainability compared to its classical counterpart as it proved to learn significantly more information after the first training epoch than its classical counterpart, learnt the local features better, all while having a comparable number of parameters. Inspired by these recent results, we proceed to test this variational quantum-classical hybrid neural network technique on stock price predictions.
#
# In the following notebook, we show a proof of concept that QLSTM can be used to great effect for stock price prediction, offering comparable and arguably better results than its classical counterpart. To do so, we implement both LSTM and QLSTM to predict the stock prices of the company Merck & Co. Inc (MRK) with the same number of features, of which we chose based on earlier studies done with stock price predictions.

# %% [markdown]
# This submission was motivated by a combination of a few separate studies:
#
# Stock price prediction use BERT and GAN: https://arxiv.org/pdf/2107.09055.pdf, Priyank Sonkiya, Vikas Bajpai, Anukriti Bansal <br>
# Quantum Long Short-Term Memory: https://arxiv.org/pdf/2009.01783.pdf, Samuel Yen-Chi Chen, Shinjae Yoo, and Yao-Lung L. Fang <br>
#
# With code and ideas reused and repurposed from the following sources:
#
# Example of a QLSTM: https://github.com/rdisipio/qlstm, Riccardo Di Sipio <br>
# How to use PyTorch LSTMs for time series regression: https://www.crosstab.io/articles/time-series-pytorch-lstm, Brian Kent <br>
# Using GANs to predict stock price movement: https://towardsdatascience.com/aifortrading-2edd6fac689d, Boris Banushev<br>

# %% [markdown]
# ## Brief Outline

# %% [markdown]
# To demonstrate the use of QLSTM for stock prediction, we use the stock prices of the company Merck & Co. Inc (MRK). The notebook will proceed in the following manner:
#
# 1. Brief description of Data
# 2. Using Classical LSTM to perform stock price prediction
# 3. Defining QLSTM and using it to perform stock price prediction
# 4. Comparison between LSTM and QLSTM
#
# Note that for the LSTM, we would be using PyTorch; while for the QLSTM we would be using PyTorch and Pennylane.

# %% [markdown]
# # Experimentation

# %% [markdown]
# - weight decay coefficient (weight decay): 0, 0.0001, 0.01
# - width of the layer (width)(controlled by hidden units): 16, 128, 512
# - mini-batch size (batch size): 1, 5, 10
# - learning rate (learning rate): 0.0001, 0.001, 0.01
# - dropout probability (dropout)(only classical for now): 0, 0.05, 0.3
# - depth of the architecture(depth): 1, 6, 12
# - sequence length: 3, 7, 30
# - num_epochs: 5, 10, 20

# %% [markdown]
# number of iterations = batch_size * num_epochs

# %%
batch_size = 1
sequence_length = 30
dropout_value = 0
num_layers = 1

weight_decay_value = 0
learning_rate = 0.0001

num_hidden_units = 16
num_epochs = 20

# %%
from torch.utils.tensorboard import SummaryWriter

# %%
writer = SummaryWriter()

# %% [markdown]
# # Data

# %% [markdown]
# To briefly describe the data, we have collected the historical data of the MRK stock prices, of which we focus on the closing price. Our goal is then to forecast the closing stock prices of MRK using LSTM (or QLSTM).
#
# To achieve this goal, we have collected the data and information we thought necessary and important. This includes the following:
#
# - Technical indicators
# - Trend approximations (Fourier Transforms)
# - ARIMA
# - Correlated assets
# - Sentimental analysis
#
# While interesting and important in its own right, we have decided not to go into detail for the data collection in this notebook. For more information, please go take a look at the Data Collection notebook also in this Github.
#
# In this section, our goal is to process the data to get it ready for the LSTM and QLSTM.

# %% [markdown]
# First, we read in the data, dropping the index and the date.

# %%
df = pd.read_csv('dataset_MRK_prediction.csv')
df = df.drop(['Date' ,'Unnamed: 0'], axis=1)
df
# Out:
#           Close    Volume        ma7       ma21      26ema      12ema  \
# 0     31.011450  14227229  30.050436  29.200291  29.514006  29.867322
# 1     31.440840  20081566  30.318975  29.299346  29.688906  30.115697
# 2     31.183207  10438080  30.564340  29.420211  29.822316  30.283528
# 3     31.364504  10302154  30.858779  29.556525  29.957940  30.452906
# 4     30.839695  12640452  30.973283  29.664667  30.034423  30.513340
# ...         ...       ...        ...        ...        ...        ...
# 2712  78.301529  13675457  75.931026  74.702836  75.305196  75.725497
# 2713  77.814888   9292930  76.515814  74.863687  75.491099  76.046941
# 2714  78.492363  10413347  77.157852  75.097238  75.713415  76.423160
# 2715  79.103050   9956838  77.684024  75.428935  75.964499  76.835451
# 2716  78.492363   8846168  77.893947  75.695202  76.151748  77.090360
#
#           MACD      20sd  upper_band  lower_band  ...        GSK         LLY  \
# 0     0.353316  0.835852   30.871996   27.528586  ...  20.441219   22.546120
# 1     0.426791  0.963549   31.226444   27.372247  ...  20.290920   22.639698
# 2     0.461212  1.026446   31.473102   27.367319  ...  20.280550   22.492653
# 3     0.494965  1.086420   31.729366   27.383684  ...  20.513784   22.800129
# 4     0.478916  1.094567   31.853801   27.475534  ...  20.285738   22.459227
# ...        ...       ...         ...         ...  ...        ...         ...
# 2712  0.420300  1.705192   78.113220   71.292452  ...  38.856968  148.141144
# 2713  0.555842  1.816324   78.496336   71.231038  ...  38.423382  146.373550
# 2714  0.709745  1.857931   78.813100   71.381377  ...  38.469505  144.916718
# 2715  0.870952  1.960788   79.350511   71.507360  ...  39.087601  144.916718
# 2716  0.938612  2.043482   79.782166   71.608238  ...  38.635563  144.839020
#
#             NVS          NYSE       NASDAQ        FT3        FT6        FT9  \
# 0     26.214659   6671.140137  2017.979980  55.454947  50.337802  47.947327
# 1     26.532934   6697.220215  2024.229980  55.359252  50.140845  47.659130
# 2     26.608170   6687.939941  2024.430054  55.263482  49.944470  47.372320
# 3     26.984316   6722.310059  2027.729980  55.167638  49.748691  47.086936
# 4     26.857002   6709.040039  2028.770020  55.071723  49.553518  46.803017
# ...         ...           ...          ...        ...        ...        ...
# 2712  82.393753  12302.190430  9682.910156  57.910147  55.622779  55.790021
# 2713  81.836136  12286.980469  9615.809570  57.817099  55.415062  55.480641
# 2714  82.576424  12641.440430  9814.080078  57.723926  55.207594  55.171523
# 2715  82.364914  12836.599609  9924.750000  57.630627  55.000389  54.862711
# 2716  85.018433  12619.519531  9953.750000  57.537207  54.793461  54.554253
#
#           ARIMA  Close_lead1
# 0     31.011450    31.440840
# 1     31.440840    31.183207
# 2     31.183207    31.364504
# 3     31.364504    30.839695
# 4     30.839695    30.944656
# ...         ...          ...
# 2712  76.887436    77.814888
# 2713  78.191500    78.492363
# 2714  77.972240    79.103050
# 2715  78.309688    78.492363
# 2716  79.039159    78.024811
#
# [2717 rows x 34 columns]

# %% [markdown]
# We identify the dependent and independent variables:

# %%
target = "Close_lead1"

# %%
features = list(df.columns.difference(["Close", 'Close_lead1']))
features
# Out:
# ['12ema',
#  '20sd',
#  '26ema',
#  'AMGN',
#  'ARIMA',
#  'BMY',
#  'FT3',
#  'FT6',
#  'FT9',
#  'GSK',
#  'JNJ',
#  'LLY',
#  'MACD',
#  'NASDAQ',
#  'NVS',
#  'NYSE',
#  'PFE',
#  'SNP',
#  'SNY',
#  'VTRS',
#  'VZ',
#  'Volume',
#  'ema',
#  'log_momentum',
#  'lower_band',
#  'ma21',
#  'ma7',
#  'momentum',
#  'neg',
#  'neu',
#  'pos',
#  'upper_band']

# %% [markdown]
# ## Data Processing

# %% [markdown]
# To process the data, we first split it into training and test data, where two-thirds of the data is used for training, and the last third is used for testing.

# %%
size = int(len(df) * 0.67)

df_train = df.loc[:size].copy()
df_test = df.loc[size:].copy()

# %% [markdown]
# Next, in order to ensure that some values don't inherently dominate the features due to their magnitude, we standardize their values.

# %%
target_mean = df_train[target].mean()
target_stdev = df_train[target].std()

for c in df_train.columns:
    mean = df_train[c].mean()
    stdev = df_train[c].std()

    df_train[c] = (df_train[c] - mean) / stdev
    df_test[c] = (df_test[c] - mean) / stdev

# %%
class SequenceDataset(Dataset):
    def __init__(self, dataframe, target, features, sequence_length=5):
        self.features = features
        self.target = target
        self.sequence_length = sequence_length
        self.y = torch.tensor(dataframe[self.target].values).float()
        self.X = torch.tensor(dataframe[self.features].values).float()

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, i): 
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            x = torch.cat((padding, x), 0)

        return x, self.y[i]

# %% [markdown]
# Finally, the last step in the data processing to prepare it for LSTM is to prepare the data in a sequence of past observations. Preparing LSTM on time series data means that it uses a certain number of past observations to predict the future. In this case, the sequence length decides how many days the LSTM considers in advance. If the sequence length is $n$, then the LSTM considers the last $n$ observations to predict the $n+1$th day.
#
# The sequence length we decided on is 3 for purposes of this notebook.

# %%
torch.manual_seed(101)

#batch_size = 10
#sequence_length = 3

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

X, y = next(iter(train_loader))

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: torch.Size([1, 30, 32])
# Target shape: torch.Size([1])

# %%
i = 0
for _ in train_loader:
    i += 1 
print(i)
# Out:
# 1821

# %% [markdown]
# # Classical LSTM

# %% [markdown]
# We first define two functions:
#
# - train_model: function to train the model based on the batches of data
# - test_model: function to test the model on the testing data
#
# For both, they print the loss at the end to let us know how the model is performing with regards to the data.

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()
    
    for X, y in data_loader:
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")
    return avg_loss

def test_model(data_loader, model, loss_function):
    
    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    return avg_loss

# %% [markdown]
# ## Running the Classical LSTM

# %% [markdown]
# To understand how we implemented QLSTM, we have to first understand how we implemented LSTM. LSTM follows the following structure:
#
# <img src="lstm2.jpg" alt="drawing" width="400"/>
#
# Image taken from: Quantum Long Short-Term Memory, https://arxiv.org/pdf/2009.01783.pdf. By Samuel Yen-Chi Chen, Shinjae Yoo, and Yao-Lung L. Fang
#
# Simply put, LSTM uses 4 neural network layers in each LSTM cell to perform its functions. They are:
#
# - Forget layer
# - Input layer
# - Update layer
# - Output layer
#
# You can see the corresponding layers in the W cells in the picture above. We will be skipping the technical details, as you can find better information on the theory elsewhere, but it is important to note that these 4 layers are the key to building an LSTM neural network model that we can train and eventually use to predict, and usually take the form of a normal NN layer (like a linear layer with reLU or convolutional layers).
#
# LSTMs are well studied, and there is a native implementation of it in PyTorch to begin with, so we use a slightly modified version of it for the time series LSTM that we perform here. The code for the time series LSTM was reused from:
#
# How to use PyTorch LSTMs for time series regression: https://www.crosstab.io/articles/time-series-pytorch-lstm, Brian Kent.
#
# In the following code, we train LSTM to predict future stock prices, and then test it on the test dataset. The learning rate of 0.0001 was decided after some experimentation, where we chose the learning rate that most reliably gave accurate results. The number of epochs we use is 20, by which it would have converged and thus would suffice for the purposes of this notebook. After that, we proceed to see 3 different graphs: the comparison between the real stock prices and the ones given by the model; and the evolution of test loss and training loss by epoch.

# %% [markdown]
# # Experimentation

# %%
class ShallowRegressionLSTM(nn.Module):
    def __init__(self, num_sensors, hidden_units, num_layers, dropout_value):
        super().__init__()
        self.num_sensors = num_sensors  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = num_layers
        self.dropout_value = dropout_value

        self.lstm = nn.LSTM(
            input_size=num_sensors,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers,
            dropout = self.dropout_value
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).requires_grad_()
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).requires_grad_()
        
        _, (hn, _) = self.lstm(x, (h0, c0))
        out = self.linear(hn[0]).flatten()  # First dim of Hn is num_layers, which is set to 1 above.

        return out

# %%
#learning_rate = 0.0001
#num_hidden_units = 16

model = ShallowRegressionLSTM(num_sensors=len(features), hidden_units=num_hidden_units, num_layers = num_layers,
                             dropout_value = dropout_value )
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay= weight_decay_value)

# %%
classical_loss_train = []
classical_loss_test = []
classical_time = []
print("Untrained test\n--------")
start = time.time()
test_loss = test_model(test_loader, model, loss_function)
end = time.time()
print("Execution time", end - start)
classical_loss_test.append(test_loss)

for ix_epoch in range(num_epochs):
    print(f"Epoch {ix_epoch}\n---------")
    start = time.time()
    train_loss = train_model(train_loader, model, loss_function, optimizer=optimizer)
    test_loss = test_model(test_loader, model, loss_function)
    end = time.time()
    print("Execution time", end - start)
    classical_loss_train.append(train_loss)
    classical_loss_test.append(test_loss)
    classical_time.append(end - start)
# Out:
# Untrained test
# --------
# Test loss: 8.843695409720558
# Execution time 0.9485085010528564
# Epoch 0
# ---------
# C:\Users\jonas\Anaconda3\envs\qrnn\lib\site-packages\torch\autograd\__init__.py:173: UserWarning: CUDA initialization: CUDA driver initialization failed, you might not have a CUDA gpu. (Triggered internally at  C:\cb\pytorch_1000000000000\work\c10\cuda\CUDAFunctions.cpp:109.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Train loss: 0.26903053535179217
# Test loss: 2.558229067956518
# Execution time 10.739466905593872
# Epoch 1
# ---------
# Train loss: 0.027425623942124555
# Test loss: 2.080115708178657
# Execution time 10.156185626983643
# Epoch 2
# ---------
# Train loss: 0.014651409826488743
# Test loss: 1.880463449457422
# Execution time 11.398171186447144
# Epoch 3
# ---------
# Train loss: 0.011466409103725308
# Test loss: 1.7299567270936647
# Execution time 10.065441846847534
# Epoch 4
# ---------
# Train loss: 0.009665660100516128
# Test loss: 1.5638389607905985
# Execution time 10.080070495605469
# Epoch 5
# ---------
# Train loss: 0.008534116184993713
# Test loss: 1.4977528185364961
# Execution time 11.422974586486816
# Epoch 6
# ---------
# Train loss: 0.007635210954600611
# Test loss: 1.4941606483032919
# Execution time 10.365939617156982
# Epoch 7
# ---------
# Train loss: 0.007154968377446175
# Test loss: 1.3430184580248998
# Execution time 10.58978009223938
# Epoch 8
# ---------
# Train loss: 0.006642523174740463
# Test loss: 1.3311374563957257
# Execution time 11.62504529953003
# Epoch 9
# ---------
# Train loss: 0.0062477752755259125
# Test loss: 1.3157014560056846
# Execution time 10.779899597167969
# Epoch 10
# ---------
# Train loss: 0.0059265904844863215
# Test loss: 1.2644864357701264
# Execution time 10.880334377288818
# Epoch 11
# ---------
# Train loss: 0.005733389049015091
# Test loss: 1.2790078270457652
# Execution time 10.08353877067566
# Epoch 12
# ---------
# Train loss: 0.005429852601225803
# Test loss: 1.1999793394054858
# Execution time 9.9834144115448
# Epoch 13
# ---------
# Train loss: 0.00528277451817855
# Test loss: 1.1771293346641796
# Execution time 10.103267669677734
# Epoch 14
# ---------
# Train loss: 0.005121275319244052
# Test loss: 1.1754034111725697
# Execution time 10.317107915878296
# Epoch 15
# ---------
# Train loss: 0.005014443319902931
# Test loss: 1.1047178334572274
# Execution time 10.372467756271362
# Epoch 16
# ---------
# Train loss: 0.004876032352171658
# Test loss: 1.1161553631260526
# Execution time 10.478708267211914
# Epoch 17
# ---------
# Train loss: 0.004787079514343095
# Test loss: 1.0978379007396013
# Execution time 12.902350187301636
# Epoch 18
# ---------
# Train loss: 0.004692399295199127
# Test loss: 1.0971232786646812
# Execution time 12.274765729904175
# Epoch 19
# ---------
# Train loss: 0.004560925034550416
# Test loss: 1.0692559510232447
# Execution time 11.184386014938354

# %% [markdown]
# We then use the model to predict the test set, and then compare the results of the prediction to the real values.

# %%
def predict(data_loader, model):
    """Just like `test_loop` function but keep track of the outputs instead of the loss
    function.
    """
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            y_star = model(X)
            output = torch.cat((output, y_star), 0)
    
    return output

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"
df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = pd.concat((df_train, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

print(df_out)
# Out:
#       Close_lead1  Model forecast
# 0       31.440840       30.396261
# 1       31.183207       30.503487
# 2       31.364504       30.652964
# 3       30.839695       30.792828
# 4       30.944656       30.688169
# ...           ...             ...
# 2712    77.814888       64.684677
# 2713    78.492363       64.641281
# 2714    79.103050       64.598251
# 2715    78.492363       65.030090
# 2716    78.024811       64.833290
#
# [2718 rows x 2 columns]

# %%
df_out = df_out[~df_out.index.duplicated(keep='first')]

# %%
plt.figure(figsize=(12, 7))
plt.plot(range(len(df_out)), df_out["Close_lead1"], label = "Real")
plt.plot(range(len(df_out)), df_out["Model forecast"], label = "LSTM Prediction")
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.vlines(size, ymin = 30, ymax = 90, label = "Test set start", linestyles = "dashed")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(21), classical_loss_test)
plt.ylabel('Test Loss')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 21), classical_loss_train)
plt.ylabel('Train Loss')
plt.xlabel('Epoch')
plt.show()

# %%
avg_time = sum(classical_time)/num_epochs
avg_time
# Out:
# 10.790165817737579

# %% [markdown]
# ## Number of parameters used

# %%
def count_parameters(m):
    return sum(p.numel() for p in m.parameters() if p.requires_grad)

# %%
num_par = count_parameters(model)
num_par
# Out:
# 3217

# %% [markdown]
# # Trading Strategy

# %%
def trading_model(data_loader, model, loss_function, initial_inv, initial_price):
    
    # initial seed money
    inv = initial_inv
    
    # initial price of stock
    price = initial_price
    
    # initial number of stock 
    number_stocks = 0
    
    # predicted earnings
    pred_earn = 0 
    
    # predicted stock
    pred_output = []
    
    # day
    day = 1
    
    for X, y in data_loader:
        model.eval()
        with torch.no_grad():
            output = model(X)
            
            pred_price =  output * target_stdev + target_mean
            pred_output.append(pred_price)
            print("Today's stock price: ", price)
            print("Predicted stock price for tomorrow: ", pred_price)
            
            #if predicted value next day higher than today's price
            if pred_price > price:
                number_stocks = number_stocks + inv/price
                inv = 0
                print("Day", day, ": Bought/Keep ", number_stocks, "stocks at price ", price)
                pred_earn = pred_earn + number_stocks * (pred_price - price)
                print("Predicted earnings: ", pred_earn)
                
                
            #if predicted value next day lower than (or equal to)  today's price
            else:
                inv = inv + number_stocks * price
                print("Day", day, ": Sold ", number_stocks, "at price ", price)
                number_stocks = 0
            
            # Update price
            price = y * target_stdev + target_mean
            day += 1
            print("Current number of stocks: ", number_stocks)
            print("Current seed money:", inv)
        
        model.train()
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    total_earnings = number_stocks*price + inv - initial_inv
    print(f"Trading earnings: {total_earnings}")
    print(f"Predicted earnings: {pred_earn}")
    return total_earnings, pred_earn, pred_output

# %%
initial_inv = 10000
initial_price = df_out["Close_lead1"][size - 1]

# %%
total_earnings, pred_earnings, pred_output = trading_model(test_loader, model, loss_function, initial_inv, initial_price)
# Out:
# Today's stock price:  60.620228
# Predicted stock price for tomorrow:  tensor([56.6744])
# Day 1 : Sold  0 at price  60.620228
# Current number of stocks:  0
# Current seed money: 10000.0
# Today's stock price:  tensor([60.7347])
# Predicted stock price for tomorrow:  tensor([59.0111])
# Day 2 : Sold  0 at price  tensor([60.7347])
# Current number of stocks:  0
# Current seed money: tensor([10000.])
# Today's stock price:  tensor([59.7615])
# Predicted stock price for tomorrow:  tensor([60.1886])
# Day 3 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([59.7615])
# Predicted earnings:  tensor([71.4747])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([59.8282])
# Predicted stock price for tomorrow:  tensor([60.6124])
# Day 4 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([59.8282])
# Predicted earnings:  tensor([202.6955])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([59.0363])
# Predicted stock price for tomorrow:  tensor([60.5834])
# Day 5 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([59.0363])
# Predicted earnings:  tensor([461.5799])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([59.4466])
# Predicted stock price for tomorrow:  tensor([60.6237])
# Day 6 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([59.4466])
# Predicted earnings:  tensor([658.5554])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([58.8740])
# Predicted stock price for tomorrow:  tensor([60.4322])
# Day 7 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([58.8740])
# Predicted earnings:  tensor([919.2826])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([58.8168])
# Predicted stock price for tomorrow:  tensor([60.4009])
# Day 8 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([58.8168])
# Predicted earnings:  tensor([1184.3529])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([59.3607])
# Predicted stock price for tomorrow:  tensor([60.2819])
# Day 9 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([59.3607])
# Predicted earnings:  tensor([1338.5073])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([58.9695])
# Predicted stock price for tomorrow:  tensor([59.9531])
# Day 10 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([58.9695])
# Predicted earnings:  tensor([1503.0983])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([59.3416])
# Predicted stock price for tomorrow:  tensor([60.3216])
# Day 11 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([59.3416])
# Predicted earnings:  tensor([1667.0861])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([58.3874])
# Predicted stock price for tomorrow:  tensor([59.9442])
# Day 12 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([58.3874])
# Predicted earnings:  tensor([1927.5886])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([57.9771])
# Predicted stock price for tomorrow:  tensor([59.2744])
# Day 13 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([57.9771])
# Predicted earnings:  tensor([2144.6655])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([58.3302])
# Predicted stock price for tomorrow:  tensor([58.9868])
# Day 14 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([58.3302])
# Predicted earnings:  tensor([2254.5371])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([57.4905])
# Predicted stock price for tomorrow:  tensor([58.4747])
# Day 15 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([57.4905])
# Predicted earnings:  tensor([2419.2251])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([57.5191])
# Predicted stock price for tomorrow:  tensor([58.1631])
# Day 16 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([57.5191])
# Predicted earnings:  tensor([2526.9915])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([57.3092])
# Predicted stock price for tomorrow:  tensor([57.6135])
# Day 17 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([57.3092])
# Predicted earnings:  tensor([2577.9128])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([57.3664])
# Predicted stock price for tomorrow:  tensor([57.4900])
# Day 18 : Bought/Keep  tensor([167.3319]) stocks at price  tensor([57.3664])
# Predicted earnings:  tensor([2598.5881])
# Current number of stocks:  tensor([167.3319])
# Current seed money: 0
# Today's stock price:  tensor([58.4256])
# Predicted stock price for tomorrow:  tensor([57.4949])
# Day 19 : Sold  tensor([167.3319]) at price  tensor([58.4256])
# Current number of stocks:  0
# Current seed money: tensor([9776.4639])
# Today's stock price:  tensor([58.8931])
# Predicted stock price for tomorrow:  tensor([57.6721])
# Day 20 : Sold  0 at price  tensor([58.8931])
# Current number of stocks:  0
# Current seed money: tensor([9776.4639])
# Today's stock price:  tensor([58.9599])
# Predicted stock price for tomorrow:  tensor([57.8973])
# Day 21 : Sold  0 at price  tensor([58.9599])
# Current number of stocks:  0
# Current seed money: tensor([9776.4639])
# Today's stock price:  tensor([58.9695])
# Predicted stock price for tomorrow:  tensor([57.7913])
# Day 22 : Sold  0 at price  tensor([58.9695])
# Current number of stocks:  0
# Current seed money: tensor([9776.4639])
# Today's stock price:  tensor([59.5134])
# Predicted stock price for tomorrow:  tensor([57.9900])
# Day 23 : Sold  0 at price  tensor([59.5134])
# Current number of stocks:  0
# Current seed money: tensor([9776.4639])
# Today's stock price:  tensor([59.5802])
# Predicted stock price for tomorrow:  tensor([58.2506])
# Day 24 : Sold  0 at price  tensor([59.5802])
# Current number of stocks:  0
# Current seed money: tensor([9776.4639])
# Today's stock price:  tensor([58.3397])
# Predicted stock price for tomorrow:  tensor([58.0907])
# Day 25 : Sold  0 at price  tensor([58.3397])
# Current number of stocks:  0
# Current seed money: tensor([9776.4639])
# Today's stock price:  tensor([57.7290])
# Predicted stock price for tomorrow:  tensor([57.7711])
# Day 26 : Bought/Keep  tensor([169.3510]) stocks at price  tensor([57.7290])
# Predicted earnings:  tensor([2605.7209])
# Current number of stocks:  tensor([169.3510])
# Current seed money: 0
# Today's stock price:  tensor([56.7080])
# Predicted stock price for tomorrow:  tensor([57.2445])
# Day 27 : Bought/Keep  tensor([169.3510]) stocks at price  tensor([56.7080])
# Predicted earnings:  tensor([2696.5725])
# Current number of stocks:  tensor([169.3510])
# Current seed money: 0
# Today's stock price:  tensor([56.8511])
# Predicted stock price for tomorrow:  tensor([56.8792])
# Day 28 : Bought/Keep  tensor([169.3510]) stocks at price  tensor([56.8511])
# Predicted earnings:  tensor([2701.3169])
# Current number of stocks:  tensor([169.3510])
# Current seed money: 0
# Today's stock price:  tensor([56.8321])
# Predicted stock price for tomorrow:  tensor([56.7145])
# Day 29 : Sold  tensor([169.3510]) at price  tensor([56.8321])
# Current number of stocks:  0
# Current seed money: tensor([9624.5654])
# Today's stock price:  tensor([57.0515])
# Predicted stock price for tomorrow:  tensor([56.6853])
# Day 30 : Sold  0 at price  tensor([57.0515])
# Current number of stocks:  0
# Current seed money: tensor([9624.5654])
# Today's stock price:  tensor([56.5553])
# Predicted stock price for tomorrow:  tensor([56.4340])
# Day 31 : Sold  0 at price  tensor([56.5553])
# Current number of stocks:  0
# Current seed money: tensor([9624.5654])
# Today's stock price:  tensor([56.3359])
# Predicted stock price for tomorrow:  tensor([56.5625])
# Day 32 : Bought/Keep  tensor([170.8426]) stocks at price  tensor([56.3359])
# Predicted earnings:  tensor([2740.0339])
# Current number of stocks:  tensor([170.8426])
# Current seed money: 0
# Today's stock price:  tensor([56.1737])
# Predicted stock price for tomorrow:  tensor([56.3135])
# Day 33 : Bought/Keep  tensor([170.8426]) stocks at price  tensor([56.1737])
# Predicted earnings:  tensor([2763.9250])
# Current number of stocks:  tensor([170.8426])
# Current seed money: 0
# Today's stock price:  tensor([57.3950])
# Predicted stock price for tomorrow:  tensor([56.6596])
# Day 34 : Sold  tensor([170.8426]) at price  tensor([57.3950])
# Current number of stocks:  0
# Current seed money: tensor([9805.5156])
# Today's stock price:  tensor([57.3760])
# Predicted stock price for tomorrow:  tensor([56.9246])
# Day 35 : Sold  0 at price  tensor([57.3760])
# Current number of stocks:  0
# Current seed money: tensor([9805.5156])
# Today's stock price:  tensor([57.3569])
# Predicted stock price for tomorrow:  tensor([57.0556])
# Day 36 : Sold  0 at price  tensor([57.3569])
# Current number of stocks:  0
# Current seed money: tensor([9805.5156])
# Today's stock price:  tensor([57.5095])
# Predicted stock price for tomorrow:  tensor([57.1810])
# Day 37 : Sold  0 at price  tensor([57.5095])
# Current number of stocks:  0
# Current seed money: tensor([9805.5156])
# Today's stock price:  tensor([58.3015])
# Predicted stock price for tomorrow:  tensor([57.6514])
# Day 38 : Sold  0 at price  tensor([58.3015])
# Current number of stocks:  0
# Current seed money: tensor([9805.5156])
# Today's stock price:  tensor([57.1756])
# Predicted stock price for tomorrow:  tensor([57.7830])
# Day 39 : Bought/Keep  tensor([171.4983]) stocks at price  tensor([57.1756])
# Predicted earnings:  tensor([2868.0977])
# Current number of stocks:  tensor([171.4983])
# Current seed money: 0
# Today's stock price:  tensor([58.8073])
# Predicted stock price for tomorrow:  tensor([58.2027])
# Day 40 : Sold  tensor([171.4983]) at price  tensor([58.8073])
# Current number of stocks:  0
# Current seed money: tensor([10085.3457])
# Today's stock price:  tensor([59.3607])
# Predicted stock price for tomorrow:  tensor([58.8144])
# Day 41 : Sold  0 at price  tensor([59.3607])
# Current number of stocks:  0
# Current seed money: tensor([10085.3457])
# Today's stock price:  tensor([59.4847])
# Predicted stock price for tomorrow:  tensor([59.2997])
# Day 42 : Sold  0 at price  tensor([59.4847])
# Current number of stocks:  0
# Current seed money: tensor([10085.3457])
# Today's stock price:  tensor([58.6641])
# Predicted stock price for tomorrow:  tensor([59.2280])
# Day 43 : Bought/Keep  tensor([171.9167]) stocks at price  tensor([58.6641])
# Predicted earnings:  tensor([2965.0369])
# Current number of stocks:  tensor([171.9167])
# Current seed money: 0
# Today's stock price:  tensor([58.3683])
# Predicted stock price for tomorrow:  tensor([59.0325])
# Day 44 : Bought/Keep  tensor([171.9167]) stocks at price  tensor([58.3683])
# Predicted earnings:  tensor([3079.2207])
# Current number of stocks:  tensor([171.9167])
# Current seed money: 0
# Today's stock price:  tensor([57.5668])
# Predicted stock price for tomorrow:  tensor([58.6520])
# Day 45 : Bought/Keep  tensor([171.9167]) stocks at price  tensor([57.5668])
# Predicted earnings:  tensor([3265.7817])
# Current number of stocks:  tensor([171.9167])
# Current seed money: 0
# Today's stock price:  tensor([59.6660])
# Predicted stock price for tomorrow:  tensor([59.3857])
# Day 46 : Sold  tensor([171.9167]) at price  tensor([59.6660])
# Current number of stocks:  0
# Current seed money: tensor([10257.5898])
# Today's stock price:  tensor([58.9790])
# Predicted stock price for tomorrow:  tensor([59.3836])
# Day 47 : Bought/Keep  tensor([173.9193]) stocks at price  tensor([58.9790])
# Predicted earnings:  tensor([3336.1545])
# Current number of stocks:  tensor([173.9193])
# Current seed money: 0
# Today's stock price:  tensor([58.4065])
# Predicted stock price for tomorrow:  tensor([59.2653])
# Day 48 : Bought/Keep  tensor([173.9193]) stocks at price  tensor([58.4065])
# Predicted earnings:  tensor([3485.5176])
# Current number of stocks:  tensor([173.9193])
# Current seed money: 0
# Today's stock price:  tensor([58.2824])
# Predicted stock price for tomorrow:  tensor([59.2978])
# Day 49 : Bought/Keep  tensor([173.9193]) stocks at price  tensor([58.2824])
# Predicted earnings:  tensor([3662.1021])
# Current number of stocks:  tensor([173.9193])
# Current seed money: 0
# Today's stock price:  tensor([58.3969])
# Predicted stock price for tomorrow:  tensor([59.1337])
# Day 50 : Bought/Keep  tensor([173.9193]) stocks at price  tensor([58.3969])
# Predicted earnings:  tensor([3790.2295])
# Current number of stocks:  tensor([173.9193])
# Current seed money: 0
# Today's stock price:  tensor([58.9218])
# Predicted stock price for tomorrow:  tensor([59.1271])
# Day 51 : Bought/Keep  tensor([173.9193]) stocks at price  tensor([58.9218])
# Predicted earnings:  tensor([3825.9409])
# Current number of stocks:  tensor([173.9193])
# Current seed money: 0
# Today's stock price:  tensor([58.6164])
# Predicted stock price for tomorrow:  tensor([59.1325])
# Day 52 : Bought/Keep  tensor([173.9193]) stocks at price  tensor([58.6164])
# Predicted earnings:  tensor([3915.6943])
# Current number of stocks:  tensor([173.9193])
# Current seed money: 0
# Today's stock price:  tensor([59.1508])
# Predicted stock price for tomorrow:  tensor([59.2232])
# Day 53 : Bought/Keep  tensor([173.9193]) stocks at price  tensor([59.1508])
# Predicted earnings:  tensor([3928.2971])
# Current number of stocks:  tensor([173.9193])
# Current seed money: 0
# Today's stock price:  tensor([59.2557])
# Predicted stock price for tomorrow:  tensor([59.5742])
# Day 54 : Bought/Keep  tensor([173.9193]) stocks at price  tensor([59.2557])
# Predicted earnings:  tensor([3983.6904])
# Current number of stocks:  tensor([173.9193])
# Current seed money: 0
# Today's stock price:  tensor([61.2405])
# Predicted stock price for tomorrow:  tensor([60.2281])
# Day 55 : Sold  tensor([173.9193]) at price  tensor([61.2405])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([61.3454])
# Predicted stock price for tomorrow:  tensor([60.6442])
# Day 56 : Sold  0 at price  tensor([61.3454])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([61.9656])
# Predicted stock price for tomorrow:  tensor([60.9835])
# Day 57 : Sold  0 at price  tensor([61.9656])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([61.2595])
# Predicted stock price for tomorrow:  tensor([61.0499])
# Day 58 : Sold  0 at price  tensor([61.2595])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([61.3740])
# Predicted stock price for tomorrow:  tensor([61.0102])
# Day 59 : Sold  0 at price  tensor([61.3740])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([61.4408])
# Predicted stock price for tomorrow:  tensor([61.0290])
# Day 60 : Sold  0 at price  tensor([61.4408])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([61.2118])
# Predicted stock price for tomorrow:  tensor([61.0522])
# Day 61 : Sold  0 at price  tensor([61.2118])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([61.8034])
# Predicted stock price for tomorrow:  tensor([61.1838])
# Day 62 : Sold  0 at price  tensor([61.8034])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.6527])
# Predicted stock price for tomorrow:  tensor([61.8141])
# Day 63 : Sold  0 at price  tensor([62.6527])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.1756])
# Predicted stock price for tomorrow:  tensor([62.0950])
# Day 64 : Sold  0 at price  tensor([62.1756])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.2710])
# Predicted stock price for tomorrow:  tensor([62.1241])
# Day 65 : Sold  0 at price  tensor([62.2710])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.3950])
# Predicted stock price for tomorrow:  tensor([62.0665])
# Day 66 : Sold  0 at price  tensor([62.3950])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.4809])
# Predicted stock price for tomorrow:  tensor([62.1396])
# Day 67 : Sold  0 at price  tensor([62.4809])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.2996])
# Predicted stock price for tomorrow:  tensor([62.0996])
# Day 68 : Sold  0 at price  tensor([62.2996])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.8340])
# Predicted stock price for tomorrow:  tensor([62.3276])
# Day 69 : Sold  0 at price  tensor([62.8340])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([63.1298])
# Predicted stock price for tomorrow:  tensor([62.2226])
# Day 70 : Sold  0 at price  tensor([63.1298])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.8340])
# Predicted stock price for tomorrow:  tensor([62.4479])
# Day 71 : Sold  0 at price  tensor([62.8340])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.8531])
# Predicted stock price for tomorrow:  tensor([62.3450])
# Day 72 : Sold  0 at price  tensor([62.8531])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([63.1775])
# Predicted stock price for tomorrow:  tensor([62.3842])
# Day 73 : Sold  0 at price  tensor([63.1775])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([63.0534])
# Predicted stock price for tomorrow:  tensor([62.4822])
# Day 74 : Sold  0 at price  tensor([63.0534])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([63.5305])
# Predicted stock price for tomorrow:  tensor([62.4583])
# Day 75 : Sold  0 at price  tensor([63.5305])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([63.4256])
# Predicted stock price for tomorrow:  tensor([62.4365])
# Day 76 : Sold  0 at price  tensor([63.4256])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.9389])
# Predicted stock price for tomorrow:  tensor([62.6294])
# Day 77 : Sold  0 at price  tensor([62.9389])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.7863])
# Predicted stock price for tomorrow:  tensor([62.5874])
# Day 78 : Sold  0 at price  tensor([62.7863])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.8721])
# Predicted stock price for tomorrow:  tensor([62.5207])
# Day 79 : Sold  0 at price  tensor([62.8721])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([62.5954])
# Predicted stock price for tomorrow:  tensor([62.5747])
# Day 80 : Sold  0 at price  tensor([62.5954])
# Current number of stocks:  0
# Current seed money: tensor([10650.9004])
# Today's stock price:  tensor([61.2118])
# Predicted stock price for tomorrow:  tensor([62.1573])
# Day 81 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([61.2118])
# Predicted earnings:  tensor([4148.2046])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([61.2595])
# Predicted stock price for tomorrow:  tensor([61.8724])
# Day 82 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([61.2595])
# Predicted earnings:  tensor([4254.8423])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([61.7366])
# Predicted stock price for tomorrow:  tensor([62.0014])
# Day 83 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([61.7366])
# Predicted earnings:  tensor([4300.9072])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([61.2405])
# Predicted stock price for tomorrow:  tensor([61.8932])
# Day 84 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([61.2405])
# Predicted earnings:  tensor([4414.4907])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([60.9733])
# Predicted stock price for tomorrow:  tensor([61.6415])
# Day 85 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([60.9733])
# Predicted earnings:  tensor([4530.7690])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([61.1737])
# Predicted stock price for tomorrow:  tensor([61.5954])
# Day 86 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([61.1737])
# Predicted earnings:  tensor([4604.1509])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([60.9828])
# Predicted stock price for tomorrow:  tensor([61.3878])
# Day 87 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([60.9828])
# Predicted earnings:  tensor([4674.6177])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([60.5916])
# Predicted stock price for tomorrow:  tensor([61.1520])
# Day 88 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([60.5916])
# Predicted earnings:  tensor([4772.1318])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([60.3817])
# Predicted stock price for tomorrow:  tensor([60.9062])
# Day 89 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([60.3817])
# Predicted earnings:  tensor([4863.3936])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([60.2863])
# Predicted stock price for tomorrow:  tensor([60.8228])
# Day 90 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([60.2863])
# Predicted earnings:  tensor([4956.7441])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([60.2958])
# Predicted stock price for tomorrow:  tensor([60.7126])
# Day 91 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([60.2958])
# Predicted earnings:  tensor([5029.2651])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([60.4389])
# Predicted stock price for tomorrow:  tensor([60.5959])
# Day 92 : Bought/Keep  tensor([174.0007]) stocks at price  tensor([60.4389])
# Predicted earnings:  tensor([5056.5708])
# Current number of stocks:  tensor([174.0007])
# Current seed money: 0
# Today's stock price:  tensor([60.7252])
# Predicted stock price for tomorrow:  tensor([60.5648])
# Day 93 : Sold  tensor([174.0007]) at price  tensor([60.7252])
# Current number of stocks:  0
# Current seed money: tensor([10566.2246])
# Today's stock price:  tensor([60.5439])
# Predicted stock price for tomorrow:  tensor([60.4872])
# Day 94 : Sold  0 at price  tensor([60.5439])
# Current number of stocks:  0
# Current seed money: tensor([10566.2246])
# Today's stock price:  tensor([60.6298])
# Predicted stock price for tomorrow:  tensor([60.4974])
# Day 95 : Sold  0 at price  tensor([60.6298])
# Current number of stocks:  0
# Current seed money: tensor([10566.2246])
# Today's stock price:  tensor([60.5630])
# Predicted stock price for tomorrow:  tensor([60.4449])
# Day 96 : Sold  0 at price  tensor([60.5630])
# Current number of stocks:  0
# Current seed money: tensor([10566.2246])
# Today's stock price:  tensor([60.7538])
# Predicted stock price for tomorrow:  tensor([60.3537])
# Day 97 : Sold  0 at price  tensor([60.7538])
# Current number of stocks:  0
# Current seed money: tensor([10566.2246])
# Today's stock price:  tensor([60.6584])
# Predicted stock price for tomorrow:  tensor([60.3136])
# Day 98 : Sold  0 at price  tensor([60.6584])
# Current number of stocks:  0
# Current seed money: tensor([10566.2246])
# Today's stock price:  tensor([60.3435])
# Predicted stock price for tomorrow:  tensor([60.1396])
# Day 99 : Sold  0 at price  tensor([60.3435])
# Current number of stocks:  0
# Current seed money: tensor([10566.2246])
# Today's stock price:  tensor([60.2385])
# Predicted stock price for tomorrow:  tensor([59.9524])
# Day 100 : Sold  0 at price  tensor([60.2385])
# Current number of stocks:  0
# Current seed money: tensor([10566.2246])
# Today's stock price:  tensor([59.6851])
# Predicted stock price for tomorrow:  tensor([59.7801])
# Day 101 : Bought/Keep  tensor([177.0328]) stocks at price  tensor([59.6851])
# Predicted earnings:  tensor([5073.3857])
# Current number of stocks:  tensor([177.0328])
# Current seed money: 0
# Today's stock price:  tensor([59.7137])
# Predicted stock price for tomorrow:  tensor([59.4394])
# Day 102 : Sold  tensor([177.0328]) at price  tensor([59.7137])
# Current number of stocks:  0
# Current seed money: tensor([10571.2920])
# Today's stock price:  tensor([60.1622])
# Predicted stock price for tomorrow:  tensor([59.2430])
# Day 103 : Sold  0 at price  tensor([60.1622])
# Current number of stocks:  0
# Current seed money: tensor([10571.2920])
# Today's stock price:  tensor([59.7424])
# Predicted stock price for tomorrow:  tensor([59.4946])
# Day 104 : Sold  0 at price  tensor([59.7424])
# Current number of stocks:  0
# Current seed money: tensor([10571.2920])
# Today's stock price:  tensor([59.9237])
# Predicted stock price for tomorrow:  tensor([59.3158])
# Day 105 : Sold  0 at price  tensor([59.9237])
# Current number of stocks:  0
# Current seed money: tensor([10571.2920])
# Today's stock price:  tensor([59.4179])
# Predicted stock price for tomorrow:  tensor([59.1339])
# Day 106 : Sold  0 at price  tensor([59.4179])
# Current number of stocks:  0
# Current seed money: tensor([10571.2920])
# Today's stock price:  tensor([59.7710])
# Predicted stock price for tomorrow:  tensor([59.2178])
# Day 107 : Sold  0 at price  tensor([59.7710])
# Current number of stocks:  0
# Current seed money: tensor([10571.2920])
# Today's stock price:  tensor([59.6851])
# Predicted stock price for tomorrow:  tensor([59.3882])
# Day 108 : Sold  0 at price  tensor([59.6851])
# Current number of stocks:  0
# Current seed money: tensor([10571.2920])
# Today's stock price:  tensor([59.0553])
# Predicted stock price for tomorrow:  tensor([59.1843])
# Day 109 : Bought/Keep  tensor([179.0065]) stocks at price  tensor([59.0553])
# Predicted earnings:  tensor([5096.4692])
# Current number of stocks:  tensor([179.0065])
# Current seed money: 0
# Today's stock price:  tensor([59.2939])
# Predicted stock price for tomorrow:  tensor([59.5879])
# Day 110 : Bought/Keep  tensor([179.0065]) stocks at price  tensor([59.2939])
# Predicted earnings:  tensor([5149.0928])
# Current number of stocks:  tensor([179.0065])
# Current seed money: 0
# Today's stock price:  tensor([59.4466])
# Predicted stock price for tomorrow:  tensor([59.6096])
# Day 111 : Bought/Keep  tensor([179.0065]) stocks at price  tensor([59.4466])
# Predicted earnings:  tensor([5178.2754])
# Current number of stocks:  tensor([179.0065])
# Current seed money: 0
# Today's stock price:  tensor([59.8282])
# Predicted stock price for tomorrow:  tensor([59.6162])
# Day 112 : Sold  tensor([179.0065]) at price  tensor([59.8282])
# Current number of stocks:  0
# Current seed money: tensor([10709.6465])
# Today's stock price:  tensor([59.7137])
# Predicted stock price for tomorrow:  tensor([59.6373])
# Day 113 : Sold  0 at price  tensor([59.7137])
# Current number of stocks:  0
# Current seed money: tensor([10709.6465])
# Today's stock price:  tensor([59.4752])
# Predicted stock price for tomorrow:  tensor([59.6201])
# Day 114 : Bought/Keep  tensor([180.0692]) stocks at price  tensor([59.4752])
# Predicted earnings:  tensor([5204.3716])
# Current number of stocks:  tensor([180.0692])
# Current seed money: 0
# Today's stock price:  tensor([59.5229])
# Predicted stock price for tomorrow:  tensor([59.7864])
# Day 115 : Bought/Keep  tensor([180.0692]) stocks at price  tensor([59.5229])
# Predicted earnings:  tensor([5251.8213])
# Current number of stocks:  tensor([180.0692])
# Current seed money: 0
# Today's stock price:  tensor([59.8282])
# Predicted stock price for tomorrow:  tensor([59.8195])
# Day 116 : Sold  tensor([180.0692]) at price  tensor([59.8282])
# Current number of stocks:  0
# Current seed money: tensor([10773.2207])
# Today's stock price:  tensor([60.7156])
# Predicted stock price for tomorrow:  tensor([60.1521])
# Day 117 : Sold  0 at price  tensor([60.7156])
# Current number of stocks:  0
# Current seed money: tensor([10773.2207])
# Today's stock price:  tensor([60.4771])
# Predicted stock price for tomorrow:  tensor([60.3565])
# Day 118 : Sold  0 at price  tensor([60.4771])
# Current number of stocks:  0
# Current seed money: tensor([10773.2207])
# Today's stock price:  tensor([61.0401])
# Predicted stock price for tomorrow:  tensor([60.7106])
# Day 119 : Sold  0 at price  tensor([61.0401])
# Current number of stocks:  0
# Current seed money: tensor([10773.2207])
# Today's stock price:  tensor([61.0782])
# Predicted stock price for tomorrow:  tensor([60.9855])
# Day 120 : Sold  0 at price  tensor([61.0782])
# Current number of stocks:  0
# Current seed money: tensor([10773.2207])
# Today's stock price:  tensor([60.3912])
# Predicted stock price for tomorrow:  tensor([61.1013])
# Day 121 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([60.3912])
# Predicted earnings:  tensor([5378.4907])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([61.0115])
# Predicted stock price for tomorrow:  tensor([61.1530])
# Day 122 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([61.0115])
# Predicted earnings:  tensor([5403.7397])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([61.4790])
# Predicted stock price for tomorrow:  tensor([61.6642])
# Day 123 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([61.4790])
# Predicted earnings:  tensor([5436.7803])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([60.6584])
# Predicted stock price for tomorrow:  tensor([61.1697])
# Day 124 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([60.6584])
# Predicted earnings:  tensor([5527.9932])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([60.6011])
# Predicted stock price for tomorrow:  tensor([61.3881])
# Day 125 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([60.6011])
# Predicted earnings:  tensor([5668.3843])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([60.8683])
# Predicted stock price for tomorrow:  tensor([61.4503])
# Day 126 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([60.8683])
# Predicted earnings:  tensor([5772.2075])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([60.1145])
# Predicted stock price for tomorrow:  tensor([61.1121])
# Day 127 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([60.1145])
# Predicted earnings:  tensor([5950.1665])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([60.9637])
# Predicted stock price for tomorrow:  tensor([61.4647])
# Day 128 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([60.9637])
# Predicted earnings:  tensor([6039.5352])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([60.8588])
# Predicted stock price for tomorrow:  tensor([61.5934])
# Day 129 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([60.8588])
# Predicted earnings:  tensor([6170.5767])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([61.1069])
# Predicted stock price for tomorrow:  tensor([61.5182])
# Day 130 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([61.1069])
# Predicted earnings:  tensor([6243.9590])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([61.5935])
# Predicted stock price for tomorrow:  tensor([61.6933])
# Day 131 : Bought/Keep  tensor([178.3905]) stocks at price  tensor([61.5935])
# Predicted earnings:  tensor([6261.7671])
# Current number of stocks:  tensor([178.3905])
# Current seed money: 0
# Today's stock price:  tensor([61.9561])
# Predicted stock price for tomorrow:  tensor([61.9003])
# Day 132 : Sold  tensor([178.3905]) at price  tensor([61.9561])
# Current number of stocks:  0
# Current seed money: tensor([11052.3818])
# Today's stock price:  tensor([62.0611])
# Predicted stock price for tomorrow:  tensor([61.7746])
# Day 133 : Sold  0 at price  tensor([62.0611])
# Current number of stocks:  0
# Current seed money: tensor([11052.3818])
# Today's stock price:  tensor([61.9466])
# Predicted stock price for tomorrow:  tensor([62.0751])
# Day 134 : Bought/Keep  tensor([178.4180]) stocks at price  tensor([61.9466])
# Predicted earnings:  tensor([6284.7065])
# Current number of stocks:  tensor([178.4180])
# Current seed money: 0
# Today's stock price:  tensor([61.9084])
# Predicted stock price for tomorrow:  tensor([61.9661])
# Day 135 : Bought/Keep  tensor([178.4180]) stocks at price  tensor([61.9084])
# Predicted earnings:  tensor([6295.0088])
# Current number of stocks:  tensor([178.4180])
# Current seed money: 0
# Today's stock price:  tensor([62.1279])
# Predicted stock price for tomorrow:  tensor([62.0085])
# Day 136 : Sold  tensor([178.4180]) at price  tensor([62.1279])
# Current number of stocks:  0
# Current seed money: tensor([11084.7295])
# Today's stock price:  tensor([62.2710])
# Predicted stock price for tomorrow:  tensor([62.0833])
# Day 137 : Sold  0 at price  tensor([62.2710])
# Current number of stocks:  0
# Current seed money: tensor([11084.7295])
# Today's stock price:  tensor([62.4714])
# Predicted stock price for tomorrow:  tensor([62.2147])
# Day 138 : Sold  0 at price  tensor([62.4714])
# Current number of stocks:  0
# Current seed money: tensor([11084.7295])
# Today's stock price:  tensor([62.0897])
# Predicted stock price for tomorrow:  tensor([62.2414])
# Day 139 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([62.0897])
# Predicted earnings:  tensor([6322.0962])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([61.7080])
# Predicted stock price for tomorrow:  tensor([62.1483])
# Day 140 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([61.7080])
# Predicted earnings:  tensor([6400.6953])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([61.1260])
# Predicted stock price for tomorrow:  tensor([61.9425])
# Day 141 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([61.1260])
# Predicted earnings:  tensor([6546.4629])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([60.3053])
# Predicted stock price for tomorrow:  tensor([61.6631])
# Day 142 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([60.3053])
# Predicted earnings:  tensor([6788.8672])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([61.4408])
# Predicted stock price for tomorrow:  tensor([61.6001])
# Day 143 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([61.4408])
# Predicted earnings:  tensor([6817.3013])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([61.4408])
# Predicted stock price for tomorrow:  tensor([61.7081])
# Day 144 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([61.4408])
# Predicted earnings:  tensor([6865.0112])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([60.3721])
# Predicted stock price for tomorrow:  tensor([61.3091])
# Day 145 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([60.3721])
# Predicted earnings:  tensor([7032.2769])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([60.4676])
# Predicted stock price for tomorrow:  tensor([61.0282])
# Day 146 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([60.4676])
# Predicted earnings:  tensor([7132.3740])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([60.2958])
# Predicted stock price for tomorrow:  tensor([60.6638])
# Day 147 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([60.2958])
# Predicted earnings:  tensor([7198.0776])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([60.0859])
# Predicted stock price for tomorrow:  tensor([60.7637])
# Day 148 : Bought/Keep  tensor([178.5277]) stocks at price  tensor([60.0859])
# Predicted earnings:  tensor([7319.0952])
# Current number of stocks:  tensor([178.5277])
# Current seed money: 0
# Today's stock price:  tensor([60.7634])
# Predicted stock price for tomorrow:  tensor([60.6809])
# Day 149 : Sold  tensor([178.5277]) at price  tensor([60.7634])
# Current number of stocks:  0
# Current seed money: tensor([10847.9414])
# Today's stock price:  tensor([61.5744])
# Predicted stock price for tomorrow:  tensor([60.8577])
# Day 150 : Sold  0 at price  tensor([61.5744])
# Current number of stocks:  0
# Current seed money: tensor([10847.9414])
# Today's stock price:  tensor([62.4618])
# Predicted stock price for tomorrow:  tensor([61.2751])
# Day 151 : Sold  0 at price  tensor([62.4618])
# Current number of stocks:  0
# Current seed money: tensor([10847.9414])
# Today's stock price:  tensor([62.9962])
# Predicted stock price for tomorrow:  tensor([61.7140])
# Day 152 : Sold  0 at price  tensor([62.9962])
# Current number of stocks:  0
# Current seed money: tensor([10847.9414])
# Today's stock price:  tensor([63.1298])
# Predicted stock price for tomorrow:  tensor([62.0753])
# Day 153 : Sold  0 at price  tensor([63.1298])
# Current number of stocks:  0
# Current seed money: tensor([10847.9414])
# Today's stock price:  tensor([62.9008])
# Predicted stock price for tomorrow:  tensor([62.0607])
# Day 154 : Sold  0 at price  tensor([62.9008])
# Current number of stocks:  0
# Current seed money: tensor([10847.9414])
# Today's stock price:  tensor([62.5382])
# Predicted stock price for tomorrow:  tensor([62.2867])
# Day 155 : Sold  0 at price  tensor([62.5382])
# Current number of stocks:  0
# Current seed money: tensor([10847.9414])
# Today's stock price:  tensor([62.1756])
# Predicted stock price for tomorrow:  tensor([61.8283])
# Day 156 : Sold  0 at price  tensor([62.1756])
# Current number of stocks:  0
# Current seed money: tensor([10847.9414])
# Today's stock price:  tensor([61.3931])
# Predicted stock price for tomorrow:  tensor([61.8003])
# Day 157 : Bought/Keep  tensor([176.6963]) stocks at price  tensor([61.3931])
# Predicted earnings:  tensor([7391.0474])
# Current number of stocks:  tensor([176.6963])
# Current seed money: 0
# Today's stock price:  tensor([61.1546])
# Predicted stock price for tomorrow:  tensor([61.6996])
# Day 158 : Bought/Keep  tensor([176.6963]) stocks at price  tensor([61.1546])
# Predicted earnings:  tensor([7487.3452])
# Current number of stocks:  tensor([176.6963])
# Current seed money: 0
# Today's stock price:  tensor([61.3263])
# Predicted stock price for tomorrow:  tensor([61.4600])
# Day 159 : Bought/Keep  tensor([176.6963]) stocks at price  tensor([61.3263])
# Predicted earnings:  tensor([7510.9551])
# Current number of stocks:  tensor([176.6963])
# Current seed money: 0
# Today's stock price:  tensor([61.2214])
# Predicted stock price for tomorrow:  tensor([61.0111])
# Day 160 : Sold  tensor([176.6963]) at price  tensor([61.2214])
# Current number of stocks:  0
# Current seed money: tensor([10817.5928])
# Today's stock price:  tensor([60.2099])
# Predicted stock price for tomorrow:  tensor([60.6542])
# Day 161 : Bought/Keep  tensor([179.6646]) stocks at price  tensor([60.2099])
# Predicted earnings:  tensor([7590.7676])
# Current number of stocks:  tensor([179.6646])
# Current seed money: 0
# Today's stock price:  tensor([60.2672])
# Predicted stock price for tomorrow:  tensor([60.6035])
# Day 162 : Bought/Keep  tensor([179.6646]) stocks at price  tensor([60.2672])
# Predicted earnings:  tensor([7651.1943])
# Current number of stocks:  tensor([179.6646])
# Current seed money: 0
# Today's stock price:  tensor([59.9523])
# Predicted stock price for tomorrow:  tensor([60.4888])
# Day 163 : Bought/Keep  tensor([179.6646]) stocks at price  tensor([59.9523])
# Predicted earnings:  tensor([7747.5898])
# Current number of stocks:  tensor([179.6646])
# Current seed money: 0
# Today's stock price:  tensor([59.4847])
# Predicted stock price for tomorrow:  tensor([60.2023])
# Day 164 : Bought/Keep  tensor([179.6646]) stocks at price  tensor([59.4847])
# Predicted earnings:  tensor([7876.5112])
# Current number of stocks:  tensor([179.6646])
# Current seed money: 0
# Today's stock price:  tensor([59.9046])
# Predicted stock price for tomorrow:  tensor([60.2047])
# Day 165 : Bought/Keep  tensor([179.6646]) stocks at price  tensor([59.9046])
# Predicted earnings:  tensor([7930.4292])
# Current number of stocks:  tensor([179.6646])
# Current seed money: 0
# Today's stock price:  tensor([60.0095])
# Predicted stock price for tomorrow:  tensor([60.1131])
# Day 166 : Bought/Keep  tensor([179.6646]) stocks at price  tensor([60.0095])
# Predicted earnings:  tensor([7949.0381])
# Current number of stocks:  tensor([179.6646])
# Current seed money: 0
# Today's stock price:  tensor([60.1718])
# Predicted stock price for tomorrow:  tensor([60.0821])
# Day 167 : Sold  tensor([179.6646]) at price  tensor([60.1718])
# Current number of stocks:  0
# Current seed money: tensor([10810.7354])
# Today's stock price:  tensor([59.7424])
# Predicted stock price for tomorrow:  tensor([60.0564])
# Day 168 : Bought/Keep  tensor([180.9559]) stocks at price  tensor([59.7424])
# Predicted earnings:  tensor([8005.8691])
# Current number of stocks:  tensor([180.9559])
# Current seed money: 0
# Today's stock price:  tensor([59.5515])
# Predicted stock price for tomorrow:  tensor([59.8675])
# Day 169 : Bought/Keep  tensor([180.9559]) stocks at price  tensor([59.5515])
# Predicted earnings:  tensor([8063.0410])
# Current number of stocks:  tensor([180.9559])
# Current seed money: 0
# Today's stock price:  tensor([59.7519])
# Predicted stock price for tomorrow:  tensor([59.8536])
# Day 170 : Bought/Keep  tensor([180.9559]) stocks at price  tensor([59.7519])
# Predicted earnings:  tensor([8081.4409])
# Current number of stocks:  tensor([180.9559])
# Current seed money: 0
# Today's stock price:  tensor([60.0573])
# Predicted stock price for tomorrow:  tensor([60.1541])
# Day 171 : Bought/Keep  tensor([180.9559]) stocks at price  tensor([60.0573])
# Predicted earnings:  tensor([8098.9717])
# Current number of stocks:  tensor([180.9559])
# Current seed money: 0
# Today's stock price:  tensor([59.7615])
# Predicted stock price for tomorrow:  tensor([60.2805])
# Day 172 : Bought/Keep  tensor([180.9559]) stocks at price  tensor([59.7615])
# Predicted earnings:  tensor([8192.8994])
# Current number of stocks:  tensor([180.9559])
# Current seed money: 0
# Today's stock price:  tensor([59.7042])
# Predicted stock price for tomorrow:  tensor([60.2954])
# Day 173 : Bought/Keep  tensor([180.9559]) stocks at price  tensor([59.7042])
# Predicted earnings:  tensor([8299.8730])
# Current number of stocks:  tensor([180.9559])
# Current seed money: 0
# Today's stock price:  tensor([59.5038])
# Predicted stock price for tomorrow:  tensor([60.0064])
# Day 174 : Bought/Keep  tensor([180.9559]) stocks at price  tensor([59.5038])
# Predicted earnings:  tensor([8390.8105])
# Current number of stocks:  tensor([180.9559])
# Current seed money: 0
# Today's stock price:  tensor([58.9695])
# Predicted stock price for tomorrow:  tensor([59.7293])
# Day 175 : Bought/Keep  tensor([180.9559]) stocks at price  tensor([58.9695])
# Predicted earnings:  tensor([8528.3057])
# Current number of stocks:  tensor([180.9559])
# Current seed money: 0
# Today's stock price:  tensor([60.7729])
# Predicted stock price for tomorrow:  tensor([60.0241])
# Day 176 : Sold  tensor([180.9559]) at price  tensor([60.7729])
# Current number of stocks:  0
# Current seed money: tensor([10997.2168])
# Today's stock price:  tensor([61.1737])
# Predicted stock price for tomorrow:  tensor([60.3785])
# Day 177 : Sold  0 at price  tensor([61.1737])
# Current number of stocks:  0
# Current seed money: tensor([10997.2168])
# Today's stock price:  tensor([60.9542])
# Predicted stock price for tomorrow:  tensor([60.3933])
# Day 178 : Sold  0 at price  tensor([60.9542])
# Current number of stocks:  0
# Current seed money: tensor([10997.2168])
# Today's stock price:  tensor([60.9924])
# Predicted stock price for tomorrow:  tensor([60.5887])
# Day 179 : Sold  0 at price  tensor([60.9924])
# Current number of stocks:  0
# Current seed money: tensor([10997.2168])
# Today's stock price:  tensor([60.5344])
# Predicted stock price for tomorrow:  tensor([60.4176])
# Day 180 : Sold  0 at price  tensor([60.5344])
# Current number of stocks:  0
# Current seed money: tensor([10997.2168])
# Today's stock price:  tensor([60.6107])
# Predicted stock price for tomorrow:  tensor([60.2968])
# Day 181 : Sold  0 at price  tensor([60.6107])
# Current number of stocks:  0
# Current seed money: tensor([10997.2168])
# Today's stock price:  tensor([60.2099])
# Predicted stock price for tomorrow:  tensor([60.1193])
# Day 182 : Sold  0 at price  tensor([60.2099])
# Current number of stocks:  0
# Current seed money: tensor([10997.2168])
# Today's stock price:  tensor([59.9618])
# Predicted stock price for tomorrow:  tensor([60.0262])
# Day 183 : Bought/Keep  tensor([183.4036]) stocks at price  tensor([59.9618])
# Predicted earnings:  tensor([8540.1143])
# Current number of stocks:  tensor([183.4036])
# Current seed money: 0
# Today's stock price:  tensor([59.4656])
# Predicted stock price for tomorrow:  tensor([59.9119])
# Day 184 : Bought/Keep  tensor([183.4036]) stocks at price  tensor([59.4656])
# Predicted earnings:  tensor([8621.9658])
# Current number of stocks:  tensor([183.4036])
# Current seed money: 0
# Today's stock price:  tensor([59.6279])
# Predicted stock price for tomorrow:  tensor([59.7535])
# Day 185 : Bought/Keep  tensor([183.4036]) stocks at price  tensor([59.6279])
# Predicted earnings:  tensor([8645.0137])
# Current number of stocks:  tensor([183.4036])
# Current seed money: 0
# Today's stock price:  tensor([59.3321])
# Predicted stock price for tomorrow:  tensor([59.4750])
# Day 186 : Bought/Keep  tensor([183.4036]) stocks at price  tensor([59.3321])
# Predicted earnings:  tensor([8671.2373])
# Current number of stocks:  tensor([183.4036])
# Current seed money: 0
# Today's stock price:  tensor([59.5229])
# Predicted stock price for tomorrow:  tensor([59.3130])
# Day 187 : Sold  tensor([183.4036]) at price  tensor([59.5229])
# Current number of stocks:  0
# Current seed money: tensor([10916.7158])
# Today's stock price:  tensor([59.7996])
# Predicted stock price for tomorrow:  tensor([59.3580])
# Day 188 : Sold  0 at price  tensor([59.7996])
# Current number of stocks:  0
# Current seed money: tensor([10916.7158])
# Today's stock price:  tensor([59.6374])
# Predicted stock price for tomorrow:  tensor([59.0638])
# Day 189 : Sold  0 at price  tensor([59.6374])
# Current number of stocks:  0
# Current seed money: tensor([10916.7158])
# Today's stock price:  tensor([59.8282])
# Predicted stock price for tomorrow:  tensor([58.4224])
# Day 190 : Sold  0 at price  tensor([59.8282])
# Current number of stocks:  0
# Current seed money: tensor([10916.7158])
# Today's stock price:  tensor([59.0076])
# Predicted stock price for tomorrow:  tensor([58.5984])
# Day 191 : Sold  0 at price  tensor([59.0076])
# Current number of stocks:  0
# Current seed money: tensor([10916.7158])
# Today's stock price:  tensor([58.6737])
# Predicted stock price for tomorrow:  tensor([59.1266])
# Day 192 : Bought/Keep  tensor([186.0582]) stocks at price  tensor([58.6737])
# Predicted earnings:  tensor([8755.5020])
# Current number of stocks:  tensor([186.0582])
# Current seed money: 0
# Today's stock price:  tensor([59.1317])
# Predicted stock price for tomorrow:  tensor([59.1395])
# Day 193 : Bought/Keep  tensor([186.0582]) stocks at price  tensor([59.1317])
# Predicted earnings:  tensor([8756.9531])
# Current number of stocks:  tensor([186.0582])
# Current seed money: 0
# Today's stock price:  tensor([59.5611])
# Predicted stock price for tomorrow:  tensor([59.2561])
# Day 194 : Sold  tensor([186.0582]) at price  tensor([59.5611])
# Current number of stocks:  0
# Current seed money: tensor([11081.8252])
# Today's stock price:  tensor([59.3034])
# Predicted stock price for tomorrow:  tensor([59.2716])
# ...
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([73.2347])
# Predicted stock price for tomorrow:  tensor([78.9957])
# Day 837 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([73.2347])
# Predicted earnings:  tensor([40216.9297])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([66.7176])
# Predicted stock price for tomorrow:  tensor([76.8398])
# Day 838 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([66.7176])
# Predicted earnings:  tensor([41766.8672])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([71.0687])
# Predicted stock price for tomorrow:  tensor([78.0605])
# Day 839 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([71.0687])
# Predicted earnings:  tensor([42837.4688])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([68.3492])
# Predicted stock price for tomorrow:  tensor([76.2598])
# Day 840 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([68.3492])
# Predicted earnings:  tensor([44048.7422])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([67.4905])
# Predicted stock price for tomorrow:  tensor([75.0358])
# Day 841 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([67.4905])
# Predicted earnings:  tensor([45204.0977])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([68.0916])
# Predicted stock price for tomorrow:  tensor([74.0882])
# Day 842 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([68.0916])
# Predicted earnings:  tensor([46122.3008])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([63.3588])
# Predicted stock price for tomorrow:  tensor([71.3871])
# Day 843 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([63.3588])
# Predicted earnings:  tensor([47351.6133])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([65.8874])
# Predicted stock price for tomorrow:  tensor([72.1832])
# Day 844 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([65.8874])
# Predicted earnings:  tensor([48315.6367])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([65.0954])
# Predicted stock price for tomorrow:  tensor([72.1072])
# Day 845 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([65.0954])
# Predicted earnings:  tensor([49389.2891])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([70.1622])
# Predicted stock price for tomorrow:  tensor([73.6308])
# Day 846 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([70.1622])
# Predicted earnings:  tensor([49920.4023])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([68.4447])
# Predicted stock price for tomorrow:  tensor([72.5325])
# Day 847 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([68.4447])
# Predicted earnings:  tensor([50546.3438])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([73.4256])
# Predicted stock price for tomorrow:  tensor([74.4427])
# Day 848 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([73.4256])
# Predicted earnings:  tensor([50702.0820])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([73.4160])
# Predicted stock price for tomorrow:  tensor([74.3471])
# Day 849 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([73.4160])
# Predicted earnings:  tensor([50844.6445])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([70.4198])
# Predicted stock price for tomorrow:  tensor([73.6576])
# Day 850 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([70.4198])
# Predicted earnings:  tensor([51340.4219])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([73.3492])
# Predicted stock price for tomorrow:  tensor([75.0000])
# Day 851 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([73.3492])
# Predicted earnings:  tensor([51593.1836])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([72.7576])
# Predicted stock price for tomorrow:  tensor([75.0043])
# Day 852 : Bought/Keep  tensor([153.1214]) stocks at price  tensor([72.7576])
# Predicted earnings:  tensor([51937.1914])
# Current number of stocks:  tensor([153.1214])
# Current seed money: 0
# Today's stock price:  tensor([76.6317])
# Predicted stock price for tomorrow:  tensor([76.4042])
# Day 853 : Sold  tensor([153.1214]) at price  tensor([76.6317])
# Current number of stocks:  0
# Current seed money: tensor([11733.9482])
# Today's stock price:  tensor([74.9618])
# Predicted stock price for tomorrow:  tensor([76.5679])
# Day 854 : Bought/Keep  tensor([156.5323]) stocks at price  tensor([74.9618])
# Predicted earnings:  tensor([52188.5977])
# Current number of stocks:  tensor([156.5323])
# Current seed money: 0
# Today's stock price:  tensor([77.8817])
# Predicted stock price for tomorrow:  tensor([77.0231])
# Day 855 : Sold  tensor([156.5323]) at price  tensor([77.8817])
# Current number of stocks:  0
# Current seed money: tensor([12190.9980])
# Today's stock price:  tensor([78.7118])
# Predicted stock price for tomorrow:  tensor([76.9410])
# Day 856 : Sold  0 at price  tensor([78.7118])
# Current number of stocks:  0
# Current seed money: tensor([12190.9980])
# Today's stock price:  tensor([76.8511])
# Predicted stock price for tomorrow:  tensor([77.0129])
# Day 857 : Bought/Keep  tensor([158.6313]) stocks at price  tensor([76.8511])
# Predicted earnings:  tensor([52214.2500])
# Current number of stocks:  tensor([158.6313])
# Current seed money: 0
# Today's stock price:  tensor([79.0458])
# Predicted stock price for tomorrow:  tensor([77.0200])
# Day 858 : Sold  tensor([158.6313]) at price  tensor([79.0458])
# Current number of stocks:  0
# Current seed money: tensor([12539.1396])
# Today's stock price:  tensor([78.3111])
# Predicted stock price for tomorrow:  tensor([77.0222])
# Day 859 : Sold  0 at price  tensor([78.3111])
# Current number of stocks:  0
# Current seed money: tensor([12539.1396])
# Today's stock price:  tensor([79.1985])
# Predicted stock price for tomorrow:  tensor([77.1752])
# Day 860 : Sold  0 at price  tensor([79.1985])
# Current number of stocks:  0
# Current seed money: tensor([12539.1396])
# Today's stock price:  tensor([79.6374])
# Predicted stock price for tomorrow:  tensor([77.0827])
# Day 861 : Sold  0 at price  tensor([79.6374])
# Current number of stocks:  0
# Current seed money: tensor([12539.1396])
# Today's stock price:  tensor([79.2939])
# Predicted stock price for tomorrow:  tensor([77.3320])
# Day 862 : Sold  0 at price  tensor([79.2939])
# Current number of stocks:  0
# Current seed money: tensor([12539.1396])
# Today's stock price:  tensor([74.9618])
# Predicted stock price for tomorrow:  tensor([76.9994])
# Day 863 : Bought/Keep  tensor([167.2737]) stocks at price  tensor([74.9618])
# Predicted earnings:  tensor([52555.0781])
# Current number of stocks:  tensor([167.2737])
# Current seed money: 0
# Today's stock price:  tensor([76.3168])
# Predicted stock price for tomorrow:  tensor([76.9435])
# Day 864 : Bought/Keep  tensor([167.2737]) stocks at price  tensor([76.3168])
# Predicted earnings:  tensor([52659.9023])
# Current number of stocks:  tensor([167.2737])
# Current seed money: 0
# Today's stock price:  tensor([77.1756])
# Predicted stock price for tomorrow:  tensor([77.1605])
# Day 865 : Sold  tensor([167.2737]) at price  tensor([77.1756])
# Current number of stocks:  0
# Current seed money: tensor([12909.4414])
# Today's stock price:  tensor([77.7004])
# Predicted stock price for tomorrow:  tensor([77.2619])
# Day 866 : Sold  0 at price  tensor([77.7004])
# Current number of stocks:  0
# Current seed money: tensor([12909.4414])
# Today's stock price:  tensor([80.1336])
# Predicted stock price for tomorrow:  tensor([77.4200])
# Day 867 : Sold  0 at price  tensor([80.1336])
# Current number of stocks:  0
# Current seed money: tensor([12909.4414])
# Today's stock price:  tensor([77.4618])
# Predicted stock price for tomorrow:  tensor([77.3105])
# Day 868 : Sold  0 at price  tensor([77.4618])
# Current number of stocks:  0
# Current seed money: tensor([12909.4414])
# Today's stock price:  tensor([77.0706])
# Predicted stock price for tomorrow:  tensor([77.3385])
# Day 869 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([77.0706])
# Predicted earnings:  tensor([52704.7734])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([75.7061])
# Predicted stock price for tomorrow:  tensor([77.3759])
# Day 870 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([75.7061])
# Predicted earnings:  tensor([52984.4609])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([74.1126])
# Predicted stock price for tomorrow:  tensor([77.1759])
# Day 871 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([74.1126])
# Predicted earnings:  tensor([53497.5625])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([73.3397])
# Predicted stock price for tomorrow:  tensor([76.9870])
# Day 872 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([73.3397])
# Predicted earnings:  tensor([54108.4844])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([74.4370])
# Predicted stock price for tomorrow:  tensor([76.9776])
# Day 873 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([74.4370])
# Predicted earnings:  tensor([54534.0430])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([73.5878])
# Predicted stock price for tomorrow:  tensor([76.7296])
# Day 874 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([73.5878])
# Predicted earnings:  tensor([55060.3086])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([72.1374])
# Predicted stock price for tomorrow:  tensor([76.2976])
# Day 875 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([72.1374])
# Predicted earnings:  tensor([55757.1445])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([72.9008])
# Predicted stock price for tomorrow:  tensor([76.0529])
# Day 876 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([72.9008])
# Predicted earnings:  tensor([56285.1406])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([74.3416])
# Predicted stock price for tomorrow:  tensor([76.2980])
# Day 877 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([74.3416])
# Predicted earnings:  tensor([56612.8438])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([73.6546])
# Predicted stock price for tomorrow:  tensor([75.8519])
# Day 878 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([73.6546])
# Predicted earnings:  tensor([56980.8906])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([74.3225])
# Predicted stock price for tomorrow:  tensor([75.9472])
# Day 879 : Bought/Keep  tensor([167.5015]) stocks at price  tensor([74.3225])
# Predicted earnings:  tensor([57253.0352])
# Current number of stocks:  tensor([167.5015])
# Current seed money: 0
# Today's stock price:  tensor([76.3836])
# Predicted stock price for tomorrow:  tensor([76.0055])
# Day 880 : Sold  tensor([167.5015]) at price  tensor([76.3836])
# Current number of stocks:  0
# Current seed money: tensor([12794.3643])
# Today's stock price:  tensor([76.1260])
# Predicted stock price for tomorrow:  tensor([76.1001])
# Day 881 : Sold  0 at price  tensor([76.1260])
# Current number of stocks:  0
# Current seed money: tensor([12794.3643])
# Today's stock price:  tensor([76.0687])
# Predicted stock price for tomorrow:  tensor([76.2135])
# Day 882 : Bought/Keep  tensor([168.1949]) stocks at price  tensor([76.0687])
# Predicted earnings:  tensor([57277.3906])
# Current number of stocks:  tensor([168.1949])
# Current seed money: 0
# Today's stock price:  tensor([73.9981])
# Predicted stock price for tomorrow:  tensor([76.1626])
# Day 883 : Bought/Keep  tensor([168.1949]) stocks at price  tensor([73.9981])
# Predicted earnings:  tensor([57641.4453])
# Current number of stocks:  tensor([168.1949])
# Current seed money: 0
# Today's stock price:  tensor([73.3683])
# Predicted stock price for tomorrow:  tensor([76.0779])
# Day 884 : Bought/Keep  tensor([168.1949]) stocks at price  tensor([73.3683])
# Predicted earnings:  tensor([58097.1875])
# Current number of stocks:  tensor([168.1949])
# Current seed money: 0
# Today's stock price:  tensor([73.0439])
# Predicted stock price for tomorrow:  tensor([75.8752])
# Day 885 : Bought/Keep  tensor([168.1949]) stocks at price  tensor([73.0439])
# Predicted earnings:  tensor([58573.4023])
# Current number of stocks:  tensor([168.1949])
# Current seed money: 0
# Today's stock price:  tensor([72.8721])
# Predicted stock price for tomorrow:  tensor([75.6883])
# Day 886 : Bought/Keep  tensor([168.1949]) stocks at price  tensor([72.8721])
# Predicted earnings:  tensor([59047.0625])
# Current number of stocks:  tensor([168.1949])
# Current seed money: 0
# Today's stock price:  tensor([73.7214])
# Predicted stock price for tomorrow:  tensor([75.7528])
# Day 887 : Bought/Keep  tensor([168.1949]) stocks at price  tensor([73.7214])
# Predicted earnings:  tensor([59388.7344])
# Current number of stocks:  tensor([168.1949])
# Current seed money: 0
# Today's stock price:  tensor([73.9981])
# Predicted stock price for tomorrow:  tensor([75.7605])
# Day 888 : Bought/Keep  tensor([168.1949]) stocks at price  tensor([73.9981])
# Predicted earnings:  tensor([59685.1562])
# Current number of stocks:  tensor([168.1949])
# Current seed money: 0
# Today's stock price:  tensor([75.4198])
# Predicted stock price for tomorrow:  tensor([75.9460])
# Day 889 : Bought/Keep  tensor([168.1949]) stocks at price  tensor([75.4198])
# Predicted earnings:  tensor([59773.6484])
# Current number of stocks:  tensor([168.1949])
# Current seed money: 0
# Today's stock price:  tensor([77.0229])
# Predicted stock price for tomorrow:  tensor([76.1222])
# Day 890 : Sold  tensor([168.1949]) at price  tensor([77.0229])
# Current number of stocks:  0
# Current seed money: tensor([12954.8564])
# Today's stock price:  tensor([75.9160])
# Predicted stock price for tomorrow:  tensor([76.1409])
# Day 891 : Bought/Keep  tensor([170.6472]) stocks at price  tensor([75.9160])
# Predicted earnings:  tensor([59812.0234])
# Current number of stocks:  tensor([170.6472])
# Current seed money: 0
# Today's stock price:  tensor([77.1374])
# Predicted stock price for tomorrow:  tensor([76.1881])
# Day 892 : Sold  tensor([170.6472]) at price  tensor([77.1374])
# Current number of stocks:  0
# Current seed money: tensor([13163.2803])
# Today's stock price:  tensor([78.3015])
# Predicted stock price for tomorrow:  tensor([76.2499])
# Day 893 : Sold  0 at price  tensor([78.3015])
# Current number of stocks:  0
# Current seed money: tensor([13163.2803])
# Today's stock price:  tensor([77.8149])
# Predicted stock price for tomorrow:  tensor([76.3176])
# Day 894 : Sold  0 at price  tensor([77.8149])
# Current number of stocks:  0
# Current seed money: tensor([13163.2803])
# Today's stock price:  tensor([78.4924])
# Predicted stock price for tomorrow:  tensor([76.4258])
# Day 895 : Sold  0 at price  tensor([78.4924])
# Current number of stocks:  0
# Current seed money: tensor([13163.2803])
# Today's stock price:  tensor([79.1031])
# Predicted stock price for tomorrow:  tensor([76.4318])
# Day 896 : Sold  0 at price  tensor([79.1031])
# Current number of stocks:  0
# Current seed money: tensor([13163.2803])
# Today's stock price:  tensor([78.4924])
# Predicted stock price for tomorrow:  tensor([76.5152])
# Day 897 : Sold  0 at price  tensor([78.4924])
# Current number of stocks:  0
# Current seed money: tensor([13163.2803])
# Trading earnings: tensor([3163.2803])
# Predicted earnings: tensor([59812.0234])

# %%
plt.figure(figsize=(12, 7))
plt.plot(range(len(df_out)), df_out["Close_lead1"], label = "Real")
plt.plot(range(size, len(df_out)), pred_output, label = "LSTM Trading Strategy Prediction")
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.vlines(size, ymin = 30, ymax = 90, label = "Test set start", linestyles = "dashed")
plt.legend()
plt.show()
# Out:
# C:\Users\jonas\Anaconda3\envs\qrnn\lib\site-packages\numpy\core\shape_base.py:65: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   ary = asanyarray(ary)
# C:\Users\jonas\Anaconda3\envs\qrnn\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
total_earnings
# Out:
# tensor([3163.2803])

# %%
pred_earnings
# Out:
# tensor([59812.0234])

# %% [markdown]
# # Store Values

# %%
import csv

# %%
with open('test.csv', 'a', newline='') as test_csv:
    test_csv_writer = csv.writer(test_csv)
    test_csv_writer.writerow(classical_loss_test)

# %%
with open('train.csv', 'a', newline='') as train_csv:
    train_csv_writer = csv.writer(train_csv)
    train_csv_writer.writerow(classical_loss_train)

# %%
with open('pred.csv', 'a', newline='') as pred_csv:
    pred_csv_writer = csv.writer(pred_csv)
    pred_csv_writer.writerow(df_out["Model forecast"])

# %%
with open('time.csv', 'a', newline='') as time_csv:
    time_csv_writer = csv.writer(time_csv)
    time_csv_writer.writerow([avg_time])

# %%
with open('parameters.csv', 'a', newline='') as parameters_csv:
    parameters_csv_writer = csv.writer(parameters_csv)
    parameters_csv_writer.writerow([num_par])

# %%
with open('total_earnings.csv', 'a', newline='') as total_earnings_csv:
    total_earnings_csv_writer = csv.writer(total_earnings_csv)
    total_earnings_csv_writer.writerow([total_earnings])

# %%
with open('pred_earnings.csv', 'a', newline='') as pred_earnings_csv:
    pred_earnings_csv_writer = csv.writer(pred_earnings_csv)
    pred_earnings_csv_writer.writerow([pred_earnings])

# %%
with open('pred_output.csv', 'a', newline='') as pred_output_csv:
    pred_output_csv_writer = csv.writer(pred_output_csv)
    pred_output_csv_writer.writerow(pred_output)

# %%
for i in range(len(classical_loss_test)):
    writer.add_scalar("Test loss",classical_loss_test[i], i)
    
for i in range(len(classical_loss_train)):
    writer.add_scalar("Train loss: ", classical_loss_train[i], i)
    
for i in range(len(df_out["Model forecast"])):
    writer.add_scalar("Predicted Value: ", df_out["Model forecast"][i], i)
    
for i in range(len(dpred_output)):
    writer.add_scalar("Predicted Value (Dynamic): ", pred_output, size + i)
    
writer.add_scalar("Avg Time: ", avg_time, 1)
writer.add_scalar("Number of parameters: ", num_par, 1)
writer.add_scalar("Total earnings: ", total_earnings, 1)
writer.add_scalar("Predicted earnings: ", pred_earnings, 1)
    
writer.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 10>()
#       7 for i in range(len(df_out["Model forecast"])):
#       8     writer.add_scalar("Predicted Value: ", df_out["Model forecast"][i], i)
# ---> 10 for i in range(pred_output):
#      11     writer.add_scalar("Predicted Value (Dynamic): ", pred_output, size + i)
#      13 writer.add_scalar("Avg Time: ", avg_time, 1)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# ## Complexity analysis

# %% [markdown]
# As a last point of comparison, we want to discuss the complexity analysis for the QLSTM, as well as compare the number of parameters used for the LSTM and the QLSTM.
#
# Given that we would want to eventually use the QLSTM on real quantum computers, it would be prudent to discuss its viability in terms of the number of gates and qubits used. First of all, we look at the number of qubits. As can be seen, in a barebones early version of QLSTM, we can afford to use any number of qubits, even a small number like 4 to run it. This is because we can sandwich it between two classical layers, where the classical layers help to convert the vector sizes to the correct amount, from the embedding of input features into the quantum circuit to the processing of the output measurements. This is very similar in idea to dressed quantum circuits, which was presented in:
#
# Transfer learning in hybrid classical-quantum neural networks: https://arxiv.org/abs/1912.08278, Andrea Mari, Thomas R. Bromley, Josh Izaac, Maria Schuld, Nathan Killoran
#
# In the foreseeable future in the NISQ era, we would likely be continuing to use the same technique, although the number of qubits can be increased to improve the model, making this technique useful in the NISQ era.
#
# For the number of gates used per circuit, we take a look at how the overall depth would increase as number of qubits and number of layers increases. As seen from the circuit above, the overall depth is $3 + n_l * (2 * n_q + 3)$, where $n_l, n_q$ refers to the number of layers and number of qubits respectively. Thus, the overall depth would increase linearly in both number of qubits and number of layers. What this also means is that the depth is quite easy to control, and extremely viable for the NISQ era. In this particular proof of example, we show that even when the number of layers is 1 (the smallest it can be) and the number of qubits is a small number, we still get pretty good results.

# %% [markdown]
# # Conclusion and Future Outlook

# %% [markdown]
# In this notebook, we have given the proof of concept that QLSTM can be used to great effect for stock price prediction, offering comparable results than its classical counterpart, while needed much fewer parameters to train and getting more information per epoch. All in all, this shows that this technique has a lot of potential in the financial world and more, as anything time series related can be trained using an LSTM and hence also a QLSTM. This is relevant not only to stock price predictions, but also for example company sales predictions or other key performance predictions. However, there are still many areas for improvement.
